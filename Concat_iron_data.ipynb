# %%
import pandas as pd #the csv reading library
import matplotlib.pyplot as plt #the ploting library
import glob #to get file names
import numpy as np
from pandas import Series
import seaborn as sns

# %%
#PULL UP ALL THE EXCELL FILES 
#make the path where you want to save eveything 

#files = glob.glob('../../../Data_Thesis/Iron/Fe2_GOM22SU/*.xlsx') 
#path_save = '../../../Data_Thesis/Iron/Fe2_GOM22SU.csv'

#files = glob.glob('../../../Data_Thesis/Iron/FeT_GOM22SU/*.xlsx') 
#path_save = '../../../Data_Thesis/Iron/FeT_GOM22SU.csv'

#files = glob.glob('../../../Data_Thesis/Iron/Fe2+FeT_GOM21SU/*.xlsx') 
#path_save = '../../../Data_Thesis/Iron/Fe2+FeT_GOM21SU.csv'

#files = glob.glob('../../../Data_Thesis/Iron/GOM21Fa_Export/BC/*Fe2*.xlsx') 
#path_save = '../../../Data_Thesis/Iron/GOM21FA_Fe2_BC.csv'

#files = glob.glob('../../../Data_Thesis/Iron/GOM21Fa_Export/BC/*FeT*.xlsx') 
#path_save = '../../../Data_Thesis/Iron/GOM21FA_FeT_BC.csv'

#files = glob.glob('../../../Data_Thesis/Iron/GOM21Fa_Export/RHZ/*Fe2*.xlsx') 
#path_save = '../../../Data_Thesis/Iron/GOM21FA_RZ_Fe2.csv'

#files = glob.glob('../../../Data_Thesis/Iron/GOM21Fa_Export/RHZ/*FeT*.xlsx') 
#path_save = '../../../Data_Thesis/Iron/GOM21FA_RZ_FeT.csv'

#files = glob.glob('../../../Data_Thesis/Iron/GOM21Fa_Export/PW/*Fe2*.xlsx') 
#path_save = '../../../Data_Thesis/Iron/GOM21FA_PW_Fe2.csv'

#files = glob.glob('../../../Data_Thesis/Iron/GOM21Fa_Export/PW/*FeT*.xlsx') 
#path_save = '../../../Data_Thesis/Iron/GOM21FA_PW_FeT.csv

#files = glob.glob('../../../Data_Thesis/Iron/GOM22SP_export/BC/Fe2/*.xlsx') 
#path_save = '../../../Data_Thesis/Iron/GOM22SP_BC_Fe2.csv'

#files = glob.glob('../../../Data_Thesis/Iron/GOM22SP_export/BC/FeT/BC_FeT*.xlsx') 
#path_save = '../../../Data_Thesis/Iron/GOM22SP_BC_FeT.csv'

#files = glob.glob('../../../Data_Thesis/Iron/GOM22SP_export/PW/*PW_Fe2*.xlsx') 
#path_save = '../../../Data_Thesis/Iron/GOM22SP_PW_Fe2.csv'

#files = glob.glob('../../../Data_Thesis/Iron/GOM22SP_export/PW/*PW_FeT*.xlsx') 
#path_save = '../../../Data_Thesis/Iron/GOM22SP_PW_FeT.csv'

files = glob.glob('../Dissertation_projects/Data/IRON/WC_FeT_Rerun/W*.xlsx') 
path_save = '../Dissertation_projects/Data/IRON/WC_FeT_Rerun/GOM_WC_P2FA_final_results.csv'

files
# Out:
# ['../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM2021_2119.xlsx',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM2021_2120_2121.xlsx',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM2021_2121_2122_2123.xlsx',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM2021_2124_2125_2126_2127.xlsx',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM21FA_2143_2144_2145_2146_2147.xlsx',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM21FA_2148_2149_2150_2151_2152.xlsx',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM21FA_2153_2154_2155_2158.xlsx',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM21FA_2156_2157_extras.xlsx',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM22SP_2214_2215_2216_2217.xlsx',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM22SP_2218_2223.xlsx',
# ...

# %%
#make the last 
for f in files: 
    read_file = pd.read_excel (f, sheet_name='Final Results')
    name = f[:-5]
    read_file.to_csv (name + ".csv", index = None, header=True)
    
#make the new files list the csv files much safer

#files = glob.glob('../../../Data_Thesis/Iron/Fe2_GOM22SU/*.csv')
#files = glob.glob('../../../Data_Thesis/Iron/FeT_GOM22SU/*.csv')
#files = glob.glob('../../../Data_Thesis/Iron/Fe2+FeT_GOM21SU/*.csv')
#files = glob.glob('../../../Data_Thesis/Iron/GOM21Fa_Export/BC/*Fe2*.csv')
#files = glob.glob('../../../Data_Thesis/Iron/GOM21Fa_Export/BC/*FeT*.csv')
#files = glob.glob('../../../Data_Thesis/Iron/GOM21Fa_Export/PW/*.csv')
#files = glob.glob('../../../Data_Thesis/Iron/GOM21Fa_Export/RHZ/*Fe2*.csv')
#files = glob.glob('../../../Data_Thesis/Iron/GOM21Fa_Export/RHZ/*FeT*.csv')
#files = glob.glob('../../../Data_Thesis/Iron/GOM22SP_export/BC/Fe2/*.csv')
#files = glob.glob('../../../Data_Thesis/Iron/GOM22SP_export/BC/FeT/*.csv')
#files = glob.glob('../../../Data_Thesis/Iron/GOM22SP_export/PW/*PW_Fe2*.csv')
#files = glob.glob('../../../Data_Thesis/Iron/GOM22SP_export/PW/*PW_FeT*.csv')
files = glob.glob('../Dissertation_projects/Data/IRON/WC_FeT_Rerun/*WC_FeT_GOM*.csv')


files
# Out:
# ['../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM2021_2119.csv',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM2021_2120_2121.csv',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM2021_2121_2122_2123.csv',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM2021_2124_2125_2126_2127.csv',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM21FA_2143_2144_2145_2146_2147.csv',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM21FA_2148_2149_2150_2151_2152.csv',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM21FA_2153_2154_2155_2158.csv',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM21FA_2156_2157_extras.csv',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM22SP_2214_2215_2216_2217.csv',
#  '../Dissertation_projects/Data/IRON/WC_FeT_Rerun\\WC_FeT_GOM22SP_2218_2223.csv',
# ...

# %%
#make function 
def GET_DATA(name):
    df = pd.read_csv(name, sep=',', index_col=0)
    df = pd.DataFrame(df)
    return df

# %%
#add it all up 
frames = []
for f in files:
    df = GET_DATA(f) # runs the processing function  
    frames.append(df) # adds the new col from each scan to a part of frames 
df = pd.concat(frames, axis=0, ignore_index=False)
df.index = df.index.astype(float)
df
# Out:
#           Treatment Campaign        Date Location   Depth  FeT Conc (uM)  \
# Sample ID
# 211901.0       P2FA  GOM2021  2021-07-15    St.MK  16.700       0.041865
# 211902.0       P2FA  GOM2021  2021-07-15    St.MK  16.700       0.027558
# 211903.0       P2FA  GOM2021  2021-07-15    St.MK  14.000       0.018976
# 211904.0       P2FA  GOM2021  2021-07-15    St.MK  14.000       0.021408
# 211905.0       P2FA  GOM2021  2021-07-15    St.MK  10.000       0.089984
# ...             ...      ...         ...      ...     ...            ...
# 225336.0       P2FA  GOM22SU  2022-07-23    St.MK   5.290       2.075067
# 225337.0       P2FA  GOM22SU  2022-07-23    St.MK   3.600       0.281065
# 225338.0       P2FA  GOM22SU  2022-07-23    St.MK   2.480       1.915886
# 225339.0       P2FA  GOM22SU  2022-07-23    St.MK   1.498       0.167697
# 225340.0       P2FA  GOM22SU  2022-07-23    St.MK   1.498       0.700801
#
#            FeT Conc (mg/L)         Notes
# Sample ID
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# Treatment
# Campaign
# Date
# Location
# Depth
# FeT Conc (uM)
# FeT Conc (mg/L)
# Notes

# %%
#clean up messy collumns drop the extra 
#df["Fe2_uM"] = df['Fe2 Conc (uM)']

#add the 2 depth cols together drop the extra 
df["FeT_uM"] = df["FeT Conc (uM)"]

#df = df.set_index('Sample ID')

#put it in a nicer order 
df = df[['Sample ID','FeT_uM']]
df.index= df['Sample ID']
df = df[['FeT_uM']]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 10
#       5 df["FeT_uM"] = df["FeT Conc (uM)"]
#       7 #df = df.set_index('Sample ID')
#       8
#       9 #put it in a nicer order
# ---> 10 df = df[['Sample ID','FeT_uM']]
#      11 df.index= df['Sample ID']
#      12 df = df[['FeT_uM']]
#
# File ~\anaconda3\envs\bugs\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\envs\bugs\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
# ...

# %%
#save it for later 
df.to_csv(path_save)

# %%
files = glob.glob('../../../Data_Thesis/Iron/Fe2/*.csv') 
#files = glob.glob('../../../Data_Thesis/Iron/*GOM22SU*.csv') 
files
# Out:
# []

# %%
#add it all up 
frames = []
for f in files:
    df = GET_DATA(f) # runs the processing function 
    frames.append(df) # adds the new col from each scan to a part of frames 
df_fe2 = pd.concat(frames, axis=0, ignore_index=False)
df_fe2
# Out:
#              Fe2_uM
# Sample ID
# 224341    -0.059076
# 224342    -0.052752
# 224343    -0.045487
# 224344    -0.049883
# 224345    -0.050349
# ...             ...
# 222362          NaN
# 222363          NaN
# 222364          NaN
# 222365          NaN
# 222367          NaN
#
# [991 rows x 1 columns]

# %%
files = glob.glob('../../../Data_Thesis/Iron/FeT/*.csv') 
#files = glob.glob('../../../Data_Thesis/Iron/*GOM22SU*.csv') 
files
# Out:
# ['../../../Data_Thesis/Iron/FeT\\FeT_GOM22SU.csv',
#  '../../../Data_Thesis/Iron/FeT\\GOM21FA_FeT_BC.csv',
#  '../../../Data_Thesis/Iron/FeT\\GOM21FA_RZ_FeT.csv',
#  '../../../Data_Thesis/Iron/FeT\\GOM22SP_BC_FeT.csv',
#  '../../../Data_Thesis/Iron/FeT\\GOM22SP_PW_FeT.csv']

# %%
#add it all up 
frames = []
for f in files:
    df = GET_DATA(f) # runs the processing function 
    frames.append(df) # adds the new col from each scan to a part of frames 
df_feT = pd.concat(frames, axis=0, ignore_index=False)
df_feT
# Out:
#                        FeT_uM
# Sample ID
# 224241     0.0607105618424698
# 224242     0.2327590697812168
# 224243     0.0378352896284411
# 224244     0.0420510901093594
# 224245     0.2612652918595757
# ...                       ...
# 222363      145.3261328950458
# 222364       66.7444125065994
# 222365       39.9015124868097
# 222366      61.52440096080614
# 222367     10.465573770491803
#
# [1085 rows x 1 columns]

# %%
df_2t = df_feT.join(df_fe2)
path_save = '../../../Data_Thesis/Iron/GOM_df_2t.csv'
df_2t.to_csv(path_save)
df_2t
# Out:
#                          FeT_uM                 Fe2_uM
# Sample ID
# 214731      0.02575381868052293                    NaN
# 214732       0.0373784339424998                    NaN
# 214832                      BDL  0.0028677959350762866
# 214835                      BDL                    BDL
# 214841     0.011829995749416141    0.01658810980334953
# ...                         ...                    ...
# St.16.22             324.931918              339.34492
# NaN                         NaN                    NaN
# NaN                         NaN                    NaN
# NaN                         NaN                    NaN
# NaN                         NaN                    NaN
#
# [1097 rows x 2 columns]

# %%
files = glob.glob('../../../Data_Thesis/Iron/Data_concats/*GOM*.csv')
files
# Out:
# ['../../../Data_Thesis/Iron/Data_concats\\Fe2+FeT_GOM21SU.csv',
#  '../../../Data_Thesis/Iron/Data_concats\\Fe2_GOM22SU.csv',
#  '../../../Data_Thesis/Iron/Data_concats\\FeT_GOM22SU.csv',
#  '../../../Data_Thesis/Iron/Data_concats\\GOM21FA_Fe2_BC.csv',
#  '../../../Data_Thesis/Iron/Data_concats\\GOM21FA_FeT_BC.csv',
#  '../../../Data_Thesis/Iron/Data_concats\\GOM21FA_PW.csv',
#  '../../../Data_Thesis/Iron/Data_concats\\GOM21FA_RZ_Fe2.csv',
#  '../../../Data_Thesis/Iron/Data_concats\\GOM21FA_RZ_FeT.csv',
#  '../../../Data_Thesis/Iron/Data_concats\\GOM22SP_BC_Fe2.csv',
#  '../../../Data_Thesis/Iron/Data_concats\\GOM22SP_BC_FeT.csv',
#  '../../../Data_Thesis/Iron/Data_concats\\GOM22SP_PW_Fe2.csv',
#  '../../../Data_Thesis/Iron/Data_concats\\GOM22SP_PW_FeT.csv']

# %%
frames = []
for f in files:
    df = GET_DATA(f) # runs the processing function 
    frames.append(df) # adds the new col from each scan to a part of frames 
df = pd.concat(frames, axis=0, ignore_index=False)
df
# Out:
#                        Fe2_uM              FeT_uM
# Sample ID
# 212841     0.0193383446151191    0.02025921816822
# 212842                    0.0                 0.0
# 212843     0.0038676689230238                 0.0
# 212844                    0.0  0.0850887163065241
# 212845     0.0038676689230238                 0.0
# ...                       ...                 ...
# 222363                    NaN   145.3261328950458
# 222364                    NaN    66.7444125065994
# 222365                    NaN    39.9015124868097
# 222366                    NaN   61.52440096080614
# 222367                    NaN  10.465573770491803
#
# [2741 rows x 2 columns]

# %%
path_save = '../../../Data_Thesis/Iron/IRON.csv'

#clean it up 
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

df[df < 0] = 0
df = df.replace(0, np.nan)

df['Fe3_uM'] = (df['FeT_uM'] - df['Fe2_uM']) 
df[df < 0] = 0
df = df.replace(0, np.nan)

df.to_csv(path_save)
df
# Out:
#              Fe2_uM      FeT_uM    Fe3_uM
# Sample ID
# 212841     0.019338    0.020259  0.000921
# 212842          NaN         NaN       NaN
# 212843     0.003868         NaN       NaN
# 212844          NaN    0.085089       NaN
# 212845     0.003868         NaN       NaN
# ...             ...         ...       ...
# 222363          NaN  145.326133       NaN
# 222364          NaN   66.744413       NaN
# 222365          NaN   39.901512       NaN
# 222366          NaN   61.524401       NaN
# 222367          NaN   10.465574       NaN
#
# [2741 rows x 3 columns]

# %%
import pandas as pd
df = pd.DataFrame({'Courses':["Spark","PySpark","Python","pandas"],
                      'Fee' :[20000,25000,22000,24000]},
                     index=['r1','r2','r3','r4'])
  
df1 = pd.DataFrame({'Duration':['30day','40days','35days','60days','55days'],
                      'Discount':[1000,2300,2500,2000,3000]}, 
                     index=['r1','r2','r3','r5','r6'])
 
print(df)
print(df1)

# Join two DataFrames
df2 = df.join(df1)
print(df2)

# Merge two DataFrames by index using pandas.merge()
df2 = pd.merge(df, df1, left_index=True, right_index=True)
print(df2)

# join two DataFrames with concat
df2 = pd.concat([df, df1], axis=1)
print(df2)
# Out:
#     Courses    Fee
# r1    Spark  20000
# r2  PySpark  25000
# r3   Python  22000
# r4   pandas  24000
#    Duration  Discount
# r1    30day      1000
# r2   40days      2300
# r3   35days      2500
# r5   60days      2000
# r6   55days      3000
#     Courses    Fee Duration  Discount
# r1    Spark  20000    30day    1000.0
# r2  PySpark  25000   40days    2300.0
# r3   Python  22000   35days    2500.0
# r4   pandas  24000      NaN       NaN
#     Courses    Fee Duration  Discount
# r1    Spark  20000    30day      1000
# r2  PySpark  25000   40days      2300
# r3   Python  22000   35days      2500
#     Courses      Fee Duration  Discount
# r1    Spark  20000.0    30day    1000.0
# r2  PySpark  25000.0   40days    2300.0
# r3   Python  22000.0   35days    2500.0
# r4   pandas  24000.0      NaN       NaN
# r5      NaN      NaN   60days    2000.0
# r6      NaN      NaN   55days    3000.0
