# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import xarray as xr
from pathlib import Path
import cartopy
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature
import cmocean
import cmocean.cm as cmo

from pykml import parser
from shapely.geometry import Polygon
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

from adjustText import adjust_text

from matplotlib.patches import Rectangle
from cartopy.mpl.patch import geos_to_path

# %%
df = pd.read_csv('../Cruise_2024/stations_north.csv', sep=',', index_col=0)
df
# Out:
#            Lat       Lon
# Name
# D     36.32189 -74.69269
# I     36.33083 -74.73650
# N     36.28261 -74.73404
# E     36.45317 -74.71917
# P     36.44200 -74.72000

# %%
lat_top=36.75
lat_bot=35.5
lon_left=-76
lon_rigth=-74
extent=[lon_left, lon_rigth, lat_bot, lat_top]
extent_mds = extent


# Generate text labels, longitude, and latitude
text = [x for x in df.index.ravel()]
lon = df['Lon']
lat = df['Lat']

res = '10m'


# Create the figure and axes with PlateCarree projection
fig, axes = plt.subplots(figsize=(10, 10), subplot_kw={'projection': ccrs.PlateCarree()})

# Add base map features
axes.add_feature(cfeature.COASTLINE)
axes.add_feature(cfeature.BORDERS, linestyle=':')
axes.add_feature(cfeature.NaturalEarthFeature(category='physical', 
                                            name='land',
                                            facecolor='grey', 
                                            scale=res)) 
axes.add_feature(cfeature.NaturalEarthFeature(category='physical',
                                            name='rivers_lake_centerlines',
                                            edgecolor='blue',
                                            facecolor='none',
                                            scale=res))

# Set the extent (make sure it covers your points)
axes.set_extent(extent, crs=ccrs.PlateCarree())

# Plot scatter points
mappable = axes.scatter(lon, lat,
                        c='black',
                        edgecolor='black',
                        s=50,
                        transform=ccrs.PlateCarree(),
                        zorder=2)

# Plot text labels and store them in a list for adjustment
txt = axes.text(lon[0]+.03, lat[0], text[0], 
                verticalalignment='center', horizontalalignment='center',
                fontsize=13, transform=ccrs.PlateCarree())
texts.append(txt)

# Plot text labels and store them in a list for adjustment
txt = axes.text(lon[1]-.025, lat[1], text[1], 
                verticalalignment='center', horizontalalignment='center',
                fontsize=13, transform=ccrs.PlateCarree())
texts.append(txt)

# Plot text labels and store them in a list for adjustment
txt = axes.text(lon[2]-.04, lat[2], text[2], 
                verticalalignment='center', horizontalalignment='center',
                fontsize=13, transform=ccrs.PlateCarree())
texts.append(txt)

# Plot text labels and store them in a list for adjustment
txt = axes.text(lon[3]+.04, lat[3]+.02, text[3], 
                verticalalignment='center', horizontalalignment='center',
                fontsize=13, transform=ccrs.PlateCarree())
texts.append(txt)

# Plot text labels and store them in a list for adjustment
txt = axes.text(lon[4]-.04, lat[4]-.02, text[4], 
                verticalalignment='center', horizontalalignment='center',
                fontsize=13, transform=ccrs.PlateCarree())
texts.append(txt)


# Customize the plot
plt.title('')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Save the plot

# Show the plot
plt.show()
# Out:
# C:\Users\hmlbr\AppData\Local\Temp\ipykernel_26336\1996490179.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   txt = axes.text(lon[0]+.03, lat[0], text[0],
# C:\Users\hmlbr\AppData\Local\Temp\ipykernel_26336\1996490179.py:51: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   txt = axes.text(lon[1]-.025, lat[1], text[1],
# ...

# %%
df = pd.read_csv('../Cruise_2024/stations_south.csv', sep=',', index_col=0)
df
# Out:
#          Lat      Lon
# Name
# CL8   34.144 -76.2100
# CL7   34.069 -76.0015
# CL11  34.003 -75.8700
# CL13  33.890 -75.8870
# CL5   34.143 -75.8060

# %%
lat_top=35.5
lat_bot=33
lon_left=-77.5
lon_rigth=-75
extent=[lon_left, lon_rigth, lat_bot, lat_top]
extent_mds = extent


# Generate text labels, longitude, and latitude
text = [x for x in df.index.ravel()]
lon = df['Lon']
lat = df['Lat']

res = '10m'


# Create the figure and axes with PlateCarree projection
fig, axes = plt.subplots(figsize=(10, 10), subplot_kw={'projection': ccrs.PlateCarree()})

# Add base map features
axes.add_feature(cfeature.COASTLINE)
axes.add_feature(cfeature.BORDERS, linestyle=':')
axes.add_feature(cfeature.NaturalEarthFeature(category='physical', 
                                            name='land',
                                            facecolor='grey', 
                                            scale=res)) 
axes.add_feature(cfeature.NaturalEarthFeature(category='physical',
                                            name='rivers_lake_centerlines',
                                            edgecolor='blue',
                                            facecolor='none',
                                            scale=res))

# Set the extent (make sure it covers your points)
axes.set_extent(extent, crs=ccrs.PlateCarree())

# Plot scatter points
mappable = axes.scatter(lon, lat,
                        c='black',
                        edgecolor='black',
                        s=50,
                        transform=ccrs.PlateCarree(),
                        zorder=2)

# Plot text labels and store them in a list for adjustment
txt = axes.text(lon[0], lat[0]+.05, text[0], 
                verticalalignment='center', horizontalalignment='center',
                fontsize=13, transform=ccrs.PlateCarree())
texts.append(txt)

# Plot text labels and store them in a list for adjustment
txt = axes.text(lon[1], lat[1]+.05, text[1], 
                verticalalignment='center', horizontalalignment='center',
                fontsize=13, transform=ccrs.PlateCarree())
texts.append(txt)

# Plot text labels and store them in a list for adjustment
txt = axes.text(lon[2], lat[2]+.05, text[2], 
                verticalalignment='center', horizontalalignment='center',
                fontsize=13, transform=ccrs.PlateCarree())
texts.append(txt)

# Plot text labels and store them in a list for adjustment
txt = axes.text(lon[3], lat[3]+.05, text[3], 
                verticalalignment='center', horizontalalignment='center',
                fontsize=13, transform=ccrs.PlateCarree())
texts.append(txt)

# Plot text labels and store them in a list for adjustment
txt = axes.text(lon[4], lat[4]+.05, text[4], 
                verticalalignment='center', horizontalalignment='center',
                fontsize=13, transform=ccrs.PlateCarree())
texts.append(txt)


# Customize the plot
plt.title('')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Save the plot

# Show the plot
plt.show()
# Out:
# C:\Users\hmlbr\AppData\Local\Temp\ipykernel_26336\254581500.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   txt = axes.text(lon[0], lat[0]+.05, text[0],
# C:\Users\hmlbr\AppData\Local\Temp\ipykernel_26336\254581500.py:51: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   txt = axes.text(lon[1], lat[1]+.05, text[1],
# ...

# %%
df = pd.read_csv('../Dissertation_projects/Carbon_cycling_project/KML_files_for_area_map/stations.csv', sep=',', index_col=0)
df
# Out:
#              Lat        Lon
# Name
# St.11  28.212711 -89.571360
# St.12  28.593656 -88.890999
# St.13  28.518589 -89.610482
# St.14  28.727365 -89.613951
# St.15  28.946873 -88.846049
# St.16  28.891849 -89.542663
# St.2   28.897664 -89.597111
# St.4   28.795941 -90.702223
# St.5B  28.804316 -91.332270
# St.7   28.913949 -89.865974
# St.9   28.785529 -89.602038
# St.MK  28.906441 -90.318518

# %%
from adjustText import adjust_text
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Define the extent
lat_top = 29.8
lat_bot = 28.15
lon_left = -91.6
lon_rigth = -88.7
extent = [lon_left, lon_rigth, lat_bot, lat_top
extent_gom = extent

# Generate text labels, longitude, and latitude
text = [x for x in df.index.ravel()]
lon = df['Lon']
lat = df['Lat']

res = '10m'

# Create the figure and axes with PlateCarree projection
fig, axes = plt.subplots(figsize=(10, 10), subplot_kw={'projection': ccrs.PlateCarree()})

# Add base map features
axes.add_feature(cfeature.COASTLINE)
axes.add_feature(cfeature.BORDERS, linestyle=':')
axes.add_feature(cfeature.NaturalEarthFeature(category='physical', 
                                            name='land',
                                            facecolor='grey', 
                                            scale=res)) 
axes.add_feature(cfeature.NaturalEarthFeature(category='physical',
                                            name='rivers_lake_centerlines',
                                            edgecolor='blue',
                                            facecolor='none',
                                            scale=res))

# Set the extent
axes.set_extent(extent, crs=ccrs.PlateCarree())

# Plot scatter points
mappable = axes.scatter(lon, lat,
                        c='black',
                        edgecolor='black',
                        s=50,
                        transform=ccrs.PlateCarree(),
                        zorder=2)

# Plot text labels and store them in a list for adjustment
texts = []
for i, text_entry in enumerate(text):
    txt = axes.text(lon[i], lat[i], text_entry, 
                    verticalalignment='center', horizontalalignment='center',
                    fontsize=13, transform=ccrs.PlateCarree())
    texts.append(txt)

# Adjust text to avoid overlaps
adjust_text(texts, 
            ax=axes,
            precision=0.2,  # Tuning parameter for finer adjustments
            expand_text=(.2, .2))  # Adjust distance between text and points
            #only_move={'points': 'xy', 'text': 'xy'})  # Allow movement in both directions

# Customize the plot
plt.title('')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Show the plot
plt.show()
# Out:
# C:\Users\hmlbr\AppData\Local\Temp\ipykernel_26336\1654682325.py:50: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   txt = axes.text(lon[i], lat[i], text_entry,

# %%
from adjustText import adjust_text
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Define the extent
lat_top = 25
lat_bot = 45
lon_left = -95
lon_rigth = -70
extent = [lon_left, lon_rigth, lat_bot, lat_top]

# Generate text labels, longitude, and latitude
text = [x for x in df.index.ravel()]
lon = df['Lon']
lat = df['Lat']

res = '10m'

# Create the figure and axes with PlateCarree projection
fig, axes = plt.subplots(figsize=(10, 10), subplot_kw={'projection': ccrs.PlateCarree()})

# Add base map features
axes.add_feature(cfeature.COASTLINE)
axes.add_feature(cfeature.BORDERS, linestyle=':')
axes.add_feature(cfeature.NaturalEarthFeature(category='physical', 
                                            name='land',
                                            facecolor='grey', 
                                            scale=res)) 
axes.add_feature(cfeature.NaturalEarthFeature(category='physical',
                                            name='rivers_lake_centerlines',
                                            edgecolor='blue',
                                            facecolor='none',
                                            scale=res))

# Add a rectangle to represent the smaller extent
lat_top = 29.8
lat_bot = 28.15
lon_left = -91.6
lon_rigth = -88.7
rect = Rectangle((lon_left, lat_bot),  # Bottom-left corner
                 lon_rigth - lon_left,  # Width
                 lat_top - lat_bot,  # Height
                 linewidth=2, edgecolor='red', facecolor='none', transform=ccrs.PlateCarree(), 
                 zorder=2)
axes.add_patch(rect)

# Add a rectangle to represent the smaller extent
lat_top=35.5
lat_bot=33
lon_left=-77.5
lon_rigth=-75
rect = Rectangle((lon_left, lat_bot),  # Bottom-left corner
                 lon_rigth - lon_left,  # Width
                 lat_top - lat_bot,  # Height
                 linewidth=2, edgecolor='red', facecolor='none', transform=ccrs.PlateCarree(), 
                 zorder=3)
axes.add_patch(rect)

# Add a rectangle to represent the smaller extent
lat_top=36.75
lat_bot=35.5
lon_left=-76
lon_rigth=-74
rect = Rectangle((lon_left, lat_bot),  # Bottom-left corner
                 lon_rigth - lon_left,  # Width
                 lat_top - lat_bot,  # Height
                 linewidth=2, edgecolor='red', facecolor='none', transform=ccrs.PlateCarree(), 
                 zorder=3)
axes.add_patch(rect)


# Set the extent
axes.set_extent(extent, crs=ccrs.PlateCarree())

# Show the plot
plt.show()
