# %%
import pandas as pd #the csv reading library
import matplotlib.pyplot as plt #the ploting library
import glob #to get file names
import numpy as np
from pandas import Series
import seaborn as sns
from matplotlib.pyplot import figure
import cmocean.cm as cmo
import seaborn as sns

from matplotlib.lines import Line2D
from geopy.distance import geodesic

from pylab import rcParams
from numpy import diff
from scipy import interpolate
import scipy.stats as stats

from scipy.signal import savgol_filter
from sklearn.linear_model import LinearRegression

import statsmodels.api as sm
from statsmodels.stats.anova import anova_lm
from statsmodels.formula.api import ols

import matplotlib.gridspec as gridspec

import cmocean
import cmocean.cm as cmo
import seaborn as sns

import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

from sklearn.manifold import MDS
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
import statsmodels.api as sm

# %%
df_o2 = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/O2_Summary_Stats.csv', sep=',', index_col=0)
df_riv = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/river_discharge_date.csv', sep=',', index_col=0)

flux_cdom_bc_350 = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_cdom_bc_350.csv', sep=',', index_col=0)
flux_cdom_bc_412 = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_cdom_bc_412.csv', sep=',', index_col=0)

flux_cdom_pw_350 = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_cdom_pw_350.csv', sep=',', index_col=0)
flux_cdom_pw_412 = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_cdom_pw_412.csv', sep=',', index_col=0)

flux_doc_bc = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_doc_bc.csv', sep=',', index_col=0)
flux_doc_pw = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_doc_pw.csv', sep=',', index_col=0)

flux_doc_pw = flux_doc_pw.drop("St.9_GOM2021", axis=0)
flux_doc_pw = flux_doc_pw.drop("St.4_GOM2021", axis=0)
flux_doc_pw = flux_doc_pw.drop("St.5B_GOM2021", axis=0)

flux_tn_bc = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_tn_bc.csv', sep=',', index_col=0)
flux_tn_pw = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_tn_pw.csv', sep=',', index_col=0)

flux_fe2_bc = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_fe2_bc.csv', sep=',', index_col=0)
flux_fe2_pw = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_fe2_pw.csv', sep=',', index_col=0)
flux_fe3_bc = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_fe3_bc.csv', sep=',', index_col=0)
flux_fe3_pw = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_fe3_pw.csv', sep=',', index_col=0)

#fe_stocks_5cm = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Iron_stocks_5CM.csv', sep=',', index_col=0)
fe_stocks = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Iron_stocks.csv', sep=',', index_col=0)

flux_inflection_bc = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_inflection_bc.csv', sep=',', index_col=0)

ncs_stocks = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/NCS_stocks.csv', sep=',', index_col=0)
wc_doc_stocks = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Water_col_DOC_stocks.csv', sep=',', index_col=0)

wc_doc_bottom = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/bottom_water_DOC.csv', sep=',', index_col=0)


################################


flux_cdom_bc_412_join = flux_cdom_bc_412['bc_flux_aCDOM412']
flux_cdom_bc_350_join = flux_cdom_bc_350['bc_flux_aCDOM350']

flux_cdom_pw_350_join = flux_cdom_pw_350['pw_flux_aCDOM350']
flux_cdom_pw_412_join = flux_cdom_pw_412['pw_flux_aCDOM412']


flux_doc_bc_join = flux_doc_bc['bc_flux_doc']

flux_doc_pw_join = flux_doc_pw['pw_flux_doc']
flux_doc_pw_error_join = flux_doc_pw['pw_flux_doc_error']

flux_tn_bc_join = flux_tn_bc['bc_flux_tn']

flux_tn_pw_join = flux_tn_pw['pw_flux_tn']
flux_tn_pw_error_join = flux_tn_pw['pw_flux_tn_error']

flux_fe2_bc_join = flux_fe2_bc['bc_flux_fe2']

flux_fe2_pw_join = flux_fe2_pw['pw_flux_fe2']
flux_fe2_pw_error_join = flux_fe2_pw['pw_flux_fe2_error']

flux_fe3_bc_join = flux_fe3_bc['bc_flux_fe3']

flux_fe3_pw_join = flux_fe3_pw['pw_flux_fe3']
flux_fe3_pw_error_join = flux_fe3_pw['pw_flux_fe3_error']

fe_stocks_join = fe_stocks
df_riv = df_riv.drop(columns=['date'])


df = df_o2.join(ncs_stocks)
df = df.join(df_riv)
df = df.join(wc_doc_bottom)
df = df.join(fe_stocks_join)
df = df.join(wc_doc_stocks)
df = df.join(flux_inflection_bc)

df = df.join(flux_cdom_bc_412_join)
df = df.join(flux_cdom_pw_412_join)

df = df.join(flux_cdom_bc_350_join)
df = df.join(flux_cdom_pw_350_join)

df = df.join(flux_doc_bc_join)
df = df.join(flux_doc_pw_join)
df = df.join(flux_doc_pw_error_join)

df = df.join(flux_tn_bc_join)
df = df.join(flux_tn_pw_join)
df = df.join(flux_tn_pw_error_join)

df = df.join(flux_fe2_bc_join)
df = df.join(flux_fe2_pw_join)
df = df.join(flux_fe2_pw_error_join)

df = df.join(flux_fe3_bc_join)
df = df.join(flux_fe3_pw_join)
df = df.join(flux_fe3_pw_error_join)

df['Camp'] = df["camp"]
df['Stn'] = df["station"]
df = df.drop(columns=['code.1'])

df['rgn'] = 'default'

df.loc[df['station'].isin(['St.2', 'St.16', 'St.16-2']), 'rgn'] = 'riv'
df.loc[df['station'].isin(['St.5B', 'St.MK', 'St.MK-2', 'St.ML', 'St.4', 'St.6']), 'rgn'] = 'hypox'
df.loc[df['station'].isin(['St.7', 'St.9', 'St.14', 'St.14.5']), 'rgn'] = 'shelf'
df.loc[df['station'].isin(['St.11', 'St.12', 'St.13', 'St.15']), 'rgn'] = 'slope'

df['season'] = 'default'

df.loc[df['camp'].isin(['GOM21FA']), 'season'] = 'fall'
df.loc[df['camp'].isin(['GOM22SU', 'GOM2021']), 'season'] = 'summer'
df.loc[df['camp'].isin(['GOM22SP']), 'season'] = 'spring'

df['OCkg_5cm_deep_M3'] = df['OCg_5cm_deep/M2'] / 1000
df['Skg_5cm_deep_M3'] = df['Sg_5cm_deep/M2'] / 1000
df['Nkg_5cm_deep_M3'] = df['Ng_5cm_deep/M2'] / 1000

df['Date'] = pd.to_datetime(df['date'])
df['day_of_year'] = df['Date'].dt.dayofyear

df['Fe2_m3'] = df['fe2_mol_per_m3_0_to_25cm']
df['Fe3_m3'] = df['fe3_mol_per_m3_0_to_25cm']

df['Fe2_m3_top'] = df['fe2_mol_per_m3_0_to_5cm']
df['Fe3_m3_top'] = df['fe3_mol_per_m3_0_to_5cm']

# Function to calculate distance
def calculate_distance(row):
    start = (row['latitude_bottom'], row['longitude_bottom'])
    end = (29.14805833, -89.24593056)  # Coordinates of delta
    return geodesic(start, end).kilometers

# Function to calculate distance
def calculate_lat_distance(row):
    start = (row['latitude_bottom'], row['longitude_bottom'])
    end = (29.14805833, row['longitude_bottom'])  
    return geodesic(start, end).kilometers

# Function to calculate distance
def calculate_lon_distance(row):
    start = (row['latitude_bottom'], row['longitude_bottom'])
    end = (row['latitude_bottom'], -89.24593056)  
    return geodesic(start, end).kilometers

# Function to calculate distance
def calculate_distance_af(row):
    start = (row['latitude_bottom'], row['longitude_bottom'])
    end = (29.4553889, -91.305625)  # Coordinates of delta
    return geodesic(start, end).kilometers

# Function to calculate distance
def calculate_lat_distance_af(row):
    start = (row['latitude_bottom'], row['longitude_bottom'])
    end = (29.4553889, row['longitude_bottom'])  
    return geodesic(start, end).kilometers

# Function to calculate distance
def calculate_lon_distance_af(row):
    start = (row['latitude_bottom'], row['longitude_bottom'])
    end = (row['latitude_bottom'], -91.305625)  
    return geodesic(start, end).kilometers

# Apply function to create new column
df['distance_to_delta_km'] = df.apply(calculate_distance, axis=1)
df['distance_to_delta_lat_km'] = df.apply(calculate_lat_distance, axis=1)
df['distance_to_delta_lon_km'] = df.apply(calculate_lon_distance, axis=1)

df['distance_to_af_km'] = df.apply(calculate_distance, axis=1)
df['distance_to_af_lat_km'] = df.apply(calculate_lat_distance, axis=1)
df['distance_to_af_lon_km'] = df.apply(calculate_lon_distance, axis=1)

df.to_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_Stock_O2_summary.csv')

df.columns
# Out:
# Index(['camp', 'station', 'date', 'Max_pressure', 'Pressure_dbar_surface',
#        'O2_mgL_surface', 'latitude_surface', 'longitude_surface',
#        'Pressure_dbar_bottom', 'O2_mgL_bottom', 'latitude_bottom',
#        'longitude_bottom', 'temp_surface', 'temp_bottom', 'sal_surface',
#        'sal_bottom', 'O2_uM_surface', 'O2_uM_bottom', 'Slope',
#        'Slope_pressure', 'Slope_pressure_percent', 'Camp', 'Stn',
#        'Cg_5cm_deep/M2', 'OCg_5cm_deep/M2', 'ICg_5cm_deep/M2',
#        'Ng_5cm_deep/M2', 'Sg_5cm_deep/M2', 'Cg_15cm_deep/M2',
#        'OCg_15cm_deep/M2', 'ICg_15cm_deep/M2', 'Ng_15cm_deep/M2',
#        'Sg_15cm_deep/M2', 'Cg_30cm_deep/M2', 'OCg_30cm_deep/M2',
#        'ICg_30cm_deep/M2', 'Ng_30cm_deep/M2', 'Sg_30cm_deep/M2',
#        'discharge_mi_ftps', 'discharge_af_ftps', 'discharge_mi_ftps_seven_day',
#        'discharge_af_ftps_seven_day', 'discharge_mi_ftps_14_day',
#        'discharge_mi_ftps_30_day', 'discharge_mi_ftps_60_day',
# ...

# %%
# Define the formula for linear regression
df_OM = df.dropna(subset=['OCkg_5cm_deep_M3'])
df_OM['Max_pressure_log'] = np.log(df_OM['Max_pressure']) 
df_copy = df

df_OM.hist(column='OCkg_5cm_deep_M3')
df_OM.hist(column='temp_surface')
df_OM.hist(column='Max_pressure_log')
df_OM.hist(column='discharge_mi_ftps_30_day')
df_OM.hist(column='discharge_af_ftps_30_day')
df_OM.hist(column='distance_to_delta_km')
# Out:
# C:\Users\hmlbr\AppData\Local\Temp\ipykernel_4040\1163990444.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_OM['Max_pressure_log'] = np.log(df_OM['Max_pressure'])
# array([[<Axes: title={'center': 'distance_to_delta_km'}>]], dtype=object)

# %%
x_var = 'OCkg_5cm_deep_M3'
y_var = 'distance_to_delta_km'

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
model = LinearRegression()
sub = df.dropna(subset=[x_var, y_var])
data = sub[[x_var, y_var, 'Camp']]
#data = data[data['pw_flux_doc'] < 15]
#data = data[data['pw_flux_tn'] >= 0]
subcat = data['Camp'].tolist()
X = data[[x_var]]
y = data[y_var]
model.fit(X, y)
score = model.score(X, y)
sns.scatterplot(x=x_var, y=y_var, s = 100, data=data, ax=axes, legend=False)
sns.lineplot(x=X[x_var], y=model.predict(X), ax=axes, color='black')
axes.set_xlabel(x_var.replace('OCkg_5cm_deep_M3', r'C$_{org}$ (g $m^{-3}$'), size=15)
axes.set_ylabel(y_var.replace('distance_to_delta_km', 'Distance to delta'), size=15)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
x_var = 'OCkg_5cm_deep_M3'
y_var = 'Max_pressure'

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
model = LinearRegression()
sub = df.dropna(subset=[x_var, y_var])
data = sub[[x_var, y_var, 'Camp']]
#data = data[data['pw_flux_doc'] < 15]
#data = data[data['pw_flux_tn'] >= 0]
subcat = data['Camp'].tolist()
X = data[[x_var]]
y = data[y_var]
model.fit(X, y)
score = model.score(X, y)
sns.scatterplot(x=x_var, y=y_var, s = 100, data=data, ax=axes, legend=False)
sns.lineplot(x=X[x_var], y=model.predict(X), ax=axes, color='black')
axes.set_xlabel(x_var.replace('OCkg_5cm_deep_M3', r'C$_{org}$ (g $m^{-3}$'), size=15)
axes.set_ylabel(y_var.replace('Max_pressure', 'Max pressure'), size=15)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
x_var = 'OCkg_5cm_deep_M3'
y_var = 'discharge_mi_ftps'

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
model = LinearRegression()
sub = df.dropna(subset=[x_var, y_var])
data = sub[[x_var, y_var, 'Camp']]
#data = data[data['pw_flux_doc'] < 15]
#data = data[data['pw_flux_tn'] >= 0]
subcat = data['Camp'].tolist()
X = data[[x_var]]
y = data[y_var]
model.fit(X, y)
score = model.score(X, y)
sns.scatterplot(x=x_var, y=y_var, s = 100, data=data, ax=axes, legend=False)
sns.lineplot(x=X[x_var], y=model.predict(X), ax=axes, color='black')
axes.set_xlabel(x_var.replace('OCkg_5cm_deep_M3', r'C$_{org}$ (g $m^{-3}$'), size=15)
axes.set_ylabel(y_var.replace('discharge_mi_ftps', 'Mississippi Discharge ($\mathrm{ft^3/s}$)'), size=15)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
x_var = 'OCkg_5cm_deep_M3'
y_var = 'temp_surface'

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
model = LinearRegression()
sub = df.dropna(subset=[x_var, y_var])
data = sub[[x_var, y_var, 'Camp']]
#data = data[data['pw_flux_doc'] < 15]
#data = data[data['pw_flux_tn'] >= 0]
subcat = data['Camp'].tolist()
X = data[[x_var]]
y = data[y_var]
model.fit(X, y)
score = model.score(X, y)
sns.scatterplot(x=x_var, y=y_var, s = 100, data=data, ax=axes, legend=False)
sns.lineplot(x=X[x_var], y=model.predict(X), ax=axes, color='black')
axes.set_xlabel(x_var.replace('OCkg_5cm_deep_M3', r'C$_{org}$ (g $m^{-3}$'), size=15)
axes.set_ylabel(y_var.replace('temp_surface', 'SST'), size=15)

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Define the formula for linear regression
df_OM = df.dropna(subset=['OCkg_5cm_deep_M3'])
df_copy = df

# Define the formula for linear regression
#formula = 'OCkg_5cm_deep_M3 ~ rgn * season'

#0.934
#formula = 'OCkg_5cm_deep_M3 ~ day_of_year * latitude_bottom * longitude_bottom'

#0.957
#formula = 'OCkg_5cm_deep_M3 ~ temp_surface * latitude_bottom * longitude_bottom * discharge_mi_ftps_seven_day'

#formula = 'OCkg_5cm_deep_M3 ~ discharge_mi_ftps_seven_day * latitude_bottom * longitude_bottom'

#formula = 'OCkg_5cm_deep_M3 ~ discharge_mi_ftps_seven_day:discharge_af_ftps_seven_day + distance_to_af_lon_km:distance_to_delta_km + temp_surface + Max_pressure'

#0.826
#formula = 'OCkg_5cm_deep_M3 ~ np.log(discharge_mi_ftps_30_day) + np.log(discharge_af_ftps_30_day) + distance_to_delta_km  + temp_surface + Max_pressure'

formula = 'OCkg_5cm_deep_M3 ~ discharge_mi_ftps_seven_day * discharge_af_ftps_seven_day + distance_to_af_lon_km * distance_to_delta_km + np.log(Max_pressure) + temp_surface'


# Fit the linear regression model
model = sm.formula.ols(formula=formula, data=df_OM).fit()
print(model.summary())

# Residuals
residuals = model.resid

# Plot 1: Residuals vs Fitted values
sns.residplot(x=model.fittedvalues, y=residuals, lowess=True, line_kws={'color': 'red', 'lw': 1})
plt.title('Residuals vs Fitted')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
plt.show()

# Plot 2: QQ Plot
sm.qqplot(residuals, line ='45')
plt.title('QQ Plot')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.show()

# Plot 3: Scale-Location Plot
sqrt_abs_standardized_resid = abs(residuals**0.5)
sns.regplot(x=model.fittedvalues, y=sqrt_abs_standardized_resid, lowess=True, line_kws={'color': 'red', 'lw': 1})
plt.title('Scale-Location Plot')
plt.xlabel('Fitted values')
plt.ylabel('Square root of absolute standardized residuals')
plt.show()

# Plot 4: Residuals vs Leverage Plot (Cook's distance)
sm.graphics.plot_leverage_resid2(model)
plt.title('Residuals vs Leverage')
plt.xlabel('Leverage')
plt.ylabel('Standardized Residuals')
plt.show()

# Make predictions
predicted = model.predict(df_OM)

# Insert predictions back to dataframe
df_OM['OCkg_5cm_deep_M3_pred'] = predicted

# Plot
plt.scatter(df_OM['OCkg_5cm_deep_M3'], predicted)
plt.xlabel(r'Actual C$_{org}$ '+'\n'+ 'inventory $(kg$ $m^{-3})$ in surface 0-5 cm interval')
plt.ylabel('Predicted  C$_{org}$ '+'\n'+ 'inventory $(kg$ $m^{-3})$ in surface 0-5 cm interval')
plt.title('')
plt.plot([df_OM['OCkg_5cm_deep_M3'].min(), df_OM['OCkg_5cm_deep_M3'].max()], 
         [df_OM['OCkg_5cm_deep_M3'].min(), df_OM['OCkg_5cm_deep_M3'].max()], 'r--')
plt.show()

# Extract coefficients and corresponding variables
coefficients = model.params
variables = coefficients.index.tolist()

# Make predictions
# Insert predictions back to dataframe
predicted = model.predict(df_copy)
df_copy['OCkg_5cm_deep_M3_pred'] = predicted

# Define custom colors and labels
color_map = {
    'GOM2021': 'darkred',
    'GOM21FA': 'blue',
    'GOM22SP': 'green',
    'GOM22SU': 'purple'
}

group_label_map_seas = {
    'GOM2021': 'Summer 2021',
    'GOM21FA': 'Fall 2021',
    'GOM22SP': 'Spring 2022',
    'GOM22SU': 'Summer 2022'
}

color_map_rgn = {
    'hypox': '#FCEAEA',
    'riv': '#EAEEFC',
    'slope': '#ECFCEA',
    'shelf': '#F1EAFC'
}

group_label_map = {
    'riv': 'River Stations',
    'hypox': 'Hypoxic Shelf',
    'shelf': 'Non-Hypoxic Shelf',
    'slope': 'Slope'
}

variable_label_map = {
    'OCkg_2cm_deep_M3_pred': r'PREDICTED C$_{org}$ inventory $(kg$ $m^{-3})$'+'\n'+ 'in surface 0-2 cm interval',
    'OCkg_5cm_deep_M3_pred': r'PREDICTED C$_{org}$ inventory $(kg$ $m^{-3})$'+'\n'+ 'in surface 0-25cm interval',
    'pw_flux_fe3': r'F$_{dFe(III)}$ '+'\n'+ r'(mmol $m^{-2}$ $day^{-1})$',
    'pw_flux_fe2': r'F$_{dFe(II)}$'+'\n'+ r'(mmol $m^{-2}$ $day^{-1})$',
    'pw_flux_tn': r'F$_{TDN}$ '+'\n'+ r'(mmol $m^{-2}$ $day^{-1})$',
}

variable_title_map = {
    'OCkg_2cm_deep_M3_pred': 'PREDICTED Solid Orgnaic Matter 2 cm',
    'OCkg_5cm_deep_M3_pred': 'PREDICTED Solid Orgnaic Matter 5 cm',
    'pw_flux_fe3': 'Diffusive Flux'+'\n'+r'F$_{dFe(III)}$',
    'pw_flux_fe2': 'Diffusive Flux'+'\n'+ r'F$_{dFe(II)}$',
    'pw_flux_tn': 'Diffusive Flux'+'\n'+ r'F$_{TDN}$'
}

variable_limits = {
    'OCkg_2cm_deep_M3_pred': (0, 1500), 
    'pw_flux_fe3': (-1, 5.25),
    'pw_flux_fe2': (-1, 5.25),
    'pw_flux_tn': (-1, 5)  # corrected the extra comma
}


var = 'OCkg_5cm_deep_M3_pred'

# Create a boxplot for each variable in a subplot
fig, axes = plt.subplots(1, 1, figsize=(6, 6)) 

# Loop through variables and create boxplots
sns.boxplot(data=df_copy, x='rgn', y=var, palette=color_map_rgn, order=group_label_map.keys(), ax=axes,
            flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
sns.stripplot(data=df_copy, x='rgn', y=var, hue='Camp', jitter=0.25, order=group_label_map.keys(), ax=axes,
                size = 7.5, linewidth = 1.0, edgecolor = 'black', palette=color_map)
axes.set_title(variable_title_map[var])  # Set title
axes.set_xlabel("")  # Remove x-axis label
axes.set_ylabel(variable_label_map[var])  # Remove y-axis label
    
axes.set_xticklabels([group_label_map[x.get_text()] for x in axes.get_xticklabels()])

legend_handles = [Line2D([0], [0], marker='o', color='w', label=label, markerfacecolor=color, markersize=10) for label, color in color_map.items()]
axes.legend(title='Campaign', handles=legend_handles, labels=group_label_map_seas.values(), loc='lower left')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# Print out the equation nicely
print("OCkg_5cm_deep_M3 =", end=" ")
for i, (variable, coefficient) in enumerate(zip(variables, coefficients)):
    if i != 0:
        print("+", end=" ")
    print(f"{coefficient:.4f} * {variable}", end=" ")
print()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       OCkg_5cm_deep_M3   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.678
# Method:                 Least Squares   F-statistic:                     5.211
# Date:                Thu, 04 Apr 2024   Prob (F-statistic):             0.0156
# Time:                        12:52:57   Log-Likelihood:                -2.3974
# No. Observations:                  17   AIC:                             22.79
# Df Residuals:                       8   BIC:                             30.29
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                                               coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------
# ...

# %%
# Define the formula for linear regression
#0.313
#formula = 'pw_flux_doc ~ OCkg_5cm_deep_M3 * O2_uM_bottom + discharge_mi_ftps:distance_to_delta_km'

#0.756 without outlier drop 
#0.919 with St.16_GOM21FA dropped
#formula = 'pw_flux_doc ~ OCkg_5cm_deep_M3_pred * O2_uM_bottom * Max_pressure * discharge_mi_ftps * distance_to_delta_km'

#0.848
#formula = 'pw_flux_doc ~ OCkg_5cm_deep_M3_pred * O2_uM_bottom * Max_pressure * discharge_mi_ftps_seven_day * distance_to_delta_km'

df_t = df_copy

#0.767 without outlier drop 
#0.904 with St.16_GOM21FA dropped
#formula = 'pw_flux_doc ~ OCkg_2cm_deep_M3_pred * O2_uM_bottom * Max_pressure * discharge_mi_ftps * distance_to_delta_km'

#0.840
#formula = 'pw_flux_doc ~ OCkg_5cm_deep_M3_pred * O2_uM_bottom * Max_pressure * discharge_mi_ftps_seven_day * distance_to_delta_km'
#formula = 'pw_flux_doc ~  O2_uM_bottom + Max_pressure + discharge_mi_ftps_seven_day + distance_to_delta_km'


#formula = 'pw_flux_doc ~ pw_flux_tn + pw_flux_fe3'
#formula = 'pw_flux_doc ~ pw_flux_tn * O2_uM_bottom * discharge_mi_ftps * distance_to_delta_km'
#formula = 'pw_flux_doc ~ pw_flux_tn + O2_uM_bottom + discharge_mi_ftps + distance_to_delta_km'
#formula = 'pw_flux_doc ~ OCkg_5cm_deep_M3_pred * O2_uM_bottom'

#formula = 'pw_flux_doc ~ OCkg_5cm_deep_M3_pred * O2_uM_bottom + discharge_mi_ftps * distance_to_delta_km'

#formula = 'pw_flux_doc ~ OCkg_5cm_deep_M3_pred * O2_uM_bottom * temp_bottom + pw_flux_tn * Fe2_m3 * Fe3_m3 '

#formula = 'pw_flux_doc ~ np.log(O2_uM_bottom) + Fe2_m3 + Fe3_m3 + OCkg_5cm_deep_M3_pred + np.log(Max_pressure)'

#formula = 'pw_flux_doc ~ Fe2_m3 + OCkg_5cm_deep_M3_pred * O2_uM_bottom + OCkg_5cm_deep_M3:Fe3_m3'

#0.492
#formula = 'pw_flux_doc ~ Fe2_m3 + OCkg_5cm_deep_M3 * O2_uM_bottom + OCkg_5cm_deep_M3:Fe3_m3'

#0.639
#formula = 'pw_flux_doc ~ Fe2_m3 * OCkg_5cm_deep_M3 + O2_uM_bottom * NPOC_uM_bottom_water'

#0.711
formula = 'pw_flux_doc ~ Fe2_m3_top * OCkg_5cm_deep_M3 + np.log(O2_uM_bottom:NPOC_uM_bottom_water) + np.log(O2_uM_bottom)'


formula = 'pw_flux_doc ~ Fe2_m3_top * OCkg_5cm_deep_M3 + O2_uM_bottom * NPOC_uM_bottom_water'
#formula = 'pw_flux_doc ~ Fe2_m3_top * OCkg_5cm_deep_M3 + O2_uM_bottom'


# Fit the linear regression model
#df_t = df.drop('St.16_GOM21FA')
df_t = df

model = sm.formula.ols(formula=formula, data=df_t).fit()
print(model.summary())

# Extract coefficients and corresponding variables
coefficients = model.params
variables = coefficients.index.tolist()

# Print out the equation nicely
print("pw_flux_doc =", end=" ")
for i, (variable, coefficient) in enumerate(zip(variables, coefficients)):
    if i != 0:
        print("+", end=" ")
    print(f"{coefficient:.4f} * {variable}", end=" ")
print()

# Residuals
residuals = model.resid

# Plot 1: Residuals vs Fitted values
sns.residplot(x=model.fittedvalues, y=residuals, lowess=True, line_kws={'color': 'red', 'lw': 1})
plt.title('Residuals vs Fitted')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
plt.show()

# Plot 2: QQ Plot
sm.qqplot(residuals, line ='45')
plt.title('QQ Plot')
plt.xlabel('Theoretical Quantiles')
plt.ylabel('Sample Quantiles')
plt.show()

# Plot 3: Scale-Location Plot
sqrt_abs_standardized_resid = abs(residuals**0.5)
sns.regplot(x=model.fittedvalues, y=sqrt_abs_standardized_resid, lowess=True, line_kws={'color': 'red', 'lw': 1})
plt.title('Scale-Location Plot')
plt.xlabel('Fitted values')
plt.ylabel('Square root of absolute standardized residuals')
plt.show()

# Plot 4: Residuals vs Leverage Plot (Cook's distance)
sm.graphics.plot_leverage_resid2(model)
plt.title('Residuals vs Leverage')
plt.xlabel('Leverage')
plt.ylabel('Standardized Residuals')
plt.show()

# Make predictions
predicted = model.predict(df_t)

# Insert predictions back to dataframe
df_t['pw_flux_doc_pred'] = predicted

# Plot
plt.scatter(df_t['pw_flux_doc'], predicted)
plt.xlabel(r'Actual F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
plt.ylabel(r'Predicted F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
plt.title('')
plt.plot([0, df_t['pw_flux_doc'].max()], 
         [0, df_t['pw_flux_doc'].max()], 'r--')
plt.show()


# Print out the equation nicely
print("pw_flux_doc_pred =", end=" ")
for i, (variable, coefficient) in enumerate(zip(variables, coefficients)):
    if i != 0:
        print("+", end=" ")
    print(f"{coefficient:.4f} * {variable}", end=" ")
print()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            pw_flux_doc   R-squared:                       0.527
# Model:                            OLS   Adj. R-squared:                  0.172
# Method:                 Least Squares   F-statistic:                     1.486
# Date:                Thu, 04 Apr 2024   Prob (F-statistic):              0.294
# Time:                        12:52:58   Log-Likelihood:                -35.413
# No. Observations:                  15   AIC:                             84.83
# Df Residuals:                       8   BIC:                             89.78
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
df_o2 = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/O2_Summary_Stats.csv', sep=',', index_col=0)
df_riv = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/river_discharge_date.csv', sep=',', index_col=0)

flux_cdom_bc_350 = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_cdom_bc_350.csv', sep=',', index_col=0)
flux_cdom_bc_412 = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_cdom_bc_412.csv', sep=',', index_col=0)

flux_cdom_pw_350 = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_cdom_pw_350.csv', sep=',', index_col=0)
flux_cdom_pw_412 = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_cdom_pw_412.csv', sep=',', index_col=0)


flux_doc_bc = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_doc_bc.csv', sep=',', index_col=0)
flux_doc_pw = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_doc_pw.csv', sep=',', index_col=0)

flux_doc_pw = flux_doc_pw.drop("St.9_GOM2021", axis=0)
flux_doc_pw = flux_doc_pw.drop("St.4_GOM2021", axis=0)
flux_doc_pw = flux_doc_pw.drop("St.5B_GOM2021", axis=0)

flux_tn_bc = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_tn_bc.csv', sep=',', index_col=0)
flux_tn_pw = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_tn_pw.csv', sep=',', index_col=0)

flux_fe2_bc = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_fe2_bc.csv', sep=',', index_col=0)
flux_fe2_pw = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_fe2_pw.csv', sep=',', index_col=0)
flux_fe3_bc = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_fe3_bc.csv', sep=',', index_col=0)
flux_fe3_pw = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_fe3_pw.csv', sep=',', index_col=0)

fe_stocks_5cm = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Iron_stocks_5CM.csv', sep=',', index_col=0)
fe_stocks = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Iron_stocks.csv', sep=',', index_col=0)

flux_inflection_bc = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Flux_inflection_bc.csv', sep=',', index_col=0)

ncs_stocks = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/NCS_stocks.csv', sep=',', index_col=0)
wc_doc_stocks = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/Water_col_DOC_stocks.csv', sep=',', index_col=0)

wc_doc_bottom = pd.read_csv('../Dissertation_projects/Data/Stats_data_sets/bottom_water_DOC.csv', sep=',', index_col=0)


################################


flux_cdom_bc_412_join = flux_cdom_bc_412['bc_flux_aCDOM412']
flux_cdom_bc_350_join = flux_cdom_bc_350['bc_flux_aCDOM350']

flux_cdom_pw_350_join = flux_cdom_pw_350['pw_flux_aCDOM350']
flux_cdom_pw_412_join = flux_cdom_pw_412['pw_flux_aCDOM412']


flux_doc_bc_join = flux_doc_bc['bc_flux_doc']

flux_doc_pw_join = flux_doc_pw['pw_flux_doc']
flux_doc_pw_error_join = flux_doc_pw['pw_flux_doc_error']

flux_tn_bc_join = flux_tn_bc['bc_flux_tn']

flux_tn_pw_join = flux_tn_pw['pw_flux_tn']
flux_tn_pw_error_join = flux_tn_pw['pw_flux_tn_error']

flux_fe2_bc_join = flux_fe2_bc['bc_flux_fe2']

flux_fe2_pw_join = flux_fe2_pw['pw_flux_fe2']
flux_fe2_pw_error_join = flux_fe2_pw['pw_flux_fe2_error']

flux_fe3_bc_join = flux_fe3_bc['bc_flux_fe3']

flux_fe3_pw_join = flux_fe3_pw['pw_flux_fe3']
flux_fe3_pw_error_join = flux_fe3_pw['pw_flux_fe3_error']


fe_stocks_join = fe_stocks
df_riv = df_riv.drop(columns=['date'])


df = df_o2.join(ncs_stocks)
df = df.join(df_riv)
df = df.join(wc_doc_bottom)
df = df.join(fe_stocks_join)
df = df.join(wc_doc_stocks)
df = df.join(flux_inflection_bc)

df = df.join(flux_cdom_bc_412_join)
df = df.join(flux_cdom_pw_412_join)

df = df.join(flux_cdom_bc_350_join)
df = df.join(flux_cdom_pw_350_join)

df = df.join(flux_doc_bc_join)
df = df.join(flux_doc_pw_join)
df = df.join(flux_doc_pw_error_join)

df = df.join(flux_tn_bc_join)
df = df.join(flux_tn_pw_join)
df = df.join(flux_tn_pw_error_join)

df = df.join(flux_fe2_bc_join)
df = df.join(flux_fe2_pw_join)
df = df.join(flux_fe2_pw_error_join)

df = df.join(flux_fe3_bc_join)
df = df.join(flux_fe3_pw_join)
df = df.join(flux_fe3_pw_error_join)

df['Camp'] = df["camp"]
df['Stn'] = df["station"]
df = df.drop(columns=['code.1'])

df['rgn'] = 'default'

df.loc[df['station'].isin(['St.2', 'St.16', 'St.16-2']), 'rgn'] = 'riv'
df.loc[df['station'].isin(['St.5B', 'St.MK', 'St.MK-2', 'St.ML', 'St.4', 'St.6']), 'rgn'] = 'hypox'
df.loc[df['station'].isin(['St.7', 'St.9', 'St.14', 'St.14.5']), 'rgn'] = 'shelf'
df.loc[df['station'].isin(['St.11', 'St.12', 'St.13', 'St.15']), 'rgn'] = 'slope'

df['season'] = 'default'

df.loc[df['camp'].isin(['GOM21FA']), 'season'] = 'fall'
df.loc[df['camp'].isin(['GOM22SU', 'GOM2021']), 'season'] = 'summer'
df.loc[df['camp'].isin(['GOM22SP']), 'season'] = 'spring'

df['OCkg_5cm_deep_M3'] = df['OCg_5cm_deep/M2'] / 1000
df['Skg_5cm_deep_M3'] = df['Sg_5cm_deep/M2'] / 1000
df['Nkg_5cm_deep_M3'] = df['Ng_5cm_deep/M2'] / 1000

df['Date'] = pd.to_datetime(df['date'])
df['day_of_year'] = df['Date'].dt.dayofyear

df['Fe2_m3'] = df['fe2_mol_per_m3_0_to_25cm']
df['Fe3_m3'] = df['fe3_mol_per_m3_0_to_25cm']

df['Fe2_m3_top'] = df['fe2_mol_per_m3_0_to_5cm']
df['Fe3_m3_top'] = df['fe3_mol_per_m3_0_to_5cm']

# Function to calculate distance
def calculate_distance(row):
    start = (row['latitude_bottom'], row['longitude_bottom'])
    end = (29.14805833, -89.24593056)  # Coordinates of delta
    return geodesic(start, end).kilometers

# Function to calculate distance
def calculate_lat_distance(row):
    start = (row['latitude_bottom'], row['longitude_bottom'])
    end = (29.14805833, row['longitude_bottom'])  
    return geodesic(start, end).kilometers

# Function to calculate distance
def calculate_lon_distance(row):
    start = (row['latitude_bottom'], row['longitude_bottom'])
    end = (row['latitude_bottom'], -89.24593056)  
    return geodesic(start, end).kilometers

# Function to calculate distance
def calculate_distance_af(row):
    start = (row['latitude_bottom'], row['longitude_bottom'])
    end = (29.4553889, -91.305625)  # Coordinates of delta
    return geodesic(start, end).kilometers

# Function to calculate distance
def calculate_lat_distance_af(row):
    start = (row['latitude_bottom'], row['longitude_bottom'])
    end = (29.4553889, row['longitude_bottom'])  
    return geodesic(start, end).kilometers

# Function to calculate distance
def calculate_lon_distance_af(row):
    start = (row['latitude_bottom'], row['longitude_bottom'])
    end = (row['latitude_bottom'], -91.305625)  
    return geodesic(start, end).kilometers

# Apply function to create new column
df['distance_to_delta_km'] = df.apply(calculate_distance, axis=1)
df['distance_to_delta_lat_km'] = df.apply(calculate_lat_distance, axis=1)
df['distance_to_delta_lon_km'] = df.apply(calculate_lon_distance, axis=1)

df['distance_to_af_km'] = df.apply(calculate_distance, axis=1)
df['distance_to_af_lat_km'] = df.apply(calculate_lat_distance, axis=1)
df['distance_to_af_lon_km'] = df.apply(calculate_lon_distance, axis=1)

df_copy = df

# %%
#OCkg_5cm_deep_M3 = 42.7737 * Intercept + -0.0000 * discharge_mi_ftps_seven_day + 0.0068 * discharge_af_ftps_seven_day 
#+ -0.1016 * distance_to_af_lon_km + 0.0944 * distance_to_delta_km + -1.1174 * temp_surface + -0.0151 * Max_pressure 

#pw_flux_doc_pred = 7.7701 * Intercept + -0.4539 * Fe2_m3_top + -0.5259 * OCkg_5cm_deep_M3 + 0.0206 * Fe2_m3_top:OCkg_5cm_deep_M3 
#+ 0.1352 * O2_uM_bottom + 0.1458 * NPOC_uM_bottom_water + -0.0015 * O2_uM_bottom:NPOC_uM_bottom_water 

multiplyer = 1.05

df_copy["OCkg_5cm_deep_M3_pred"] = 42.7737 + -0.0000 * df_copy['discharge_mi_ftps_seven_day'] + 0.0068 * df_copy['discharge_af_ftps_seven_day']  + -0.1016 * df_copy['distance_to_af_lon_km'] + 0.0944 * df_copy['distance_to_delta_km'] + -1.1174 * df_copy['temp_surface'] + -0.0151 * df_copy['Max_pressure']

df_copy["OCkg_5cm_deep_M3_pred_high"] = 42.7737 + -0.0000 * df_copy['discharge_mi_ftps_seven_day']*multiplyer + 0.0068 * df_copy['discharge_af_ftps_seven_day']*multiplyer  + -0.1016 * df_copy['distance_to_af_lon_km'] + 0.0944 * df_copy['distance_to_delta_km'] + -1.1174 * df_copy['temp_surface'] + -0.0151 * df_copy['Max_pressure']

#pw_flux_doc = 90.8144 * Intercept + -0.1984 * Fe2_m3 + -3.5399 * OCkg_5cm_deep_M3_pred 
#+ -0.5174 * O2_uM_bottom + 0.0222 * OCkg_5cm_deep_M3_pred:O2_uM_bottom + 0.0047 * OCkg_5cm_deep_M3:Fe3_m3 

df_copy['O2_uM_bottom_low'] = df_copy['O2_uM_bottom']/multiplyer

#df_copy["pw_flux_doc_pred"] = 64.7129  + -0.1950 * df_copy['Fe2_m3'] + -2.3015 * df_copy['OCkg_5cm_deep_M3'] + -0.3396 * df_copy['O2_uM_bottom'] + 0.0135 * df_copy['OCkg_5cm_deep_M3'] * df_copy['O2_uM_bottom'] + 0.0053 * df_copy['OCkg_5cm_deep_M3'] * df_copy['Fe3_m3'] 
#df_copy["pw_flux_doc_pred"] = 64.7129  + -0.1950 * df_copy['Fe2_m3'] + -2.3015 * df_copy['OCkg_5cm_deep_M3_pred'] + -0.3396 * df_copy['O2_uM_bottom'] + 0.0135 * df_copy['OCkg_5cm_deep_M3_pred'] * df_copy['O2_uM_bottom'] + 0.0053 * df_copy['OCkg_5cm_deep_M3_pred'] * df_copy['Fe3_m3'] 
#df_copy["pw_flux_doc_pred_precip"] =  64.7129  + -0.1950 * df_copy['Fe2_m3'] + -2.3015 * df_copy['OCkg_5cm_deep_M3_pred_high'] + -0.3396 * df_copy['O2_uM_bottom'] + 0.0135 * df_copy['OCkg_5cm_deep_M3_pred_high'] * df_copy['O2_uM_bottom'] + 0.0053 * df_copy['OCkg_5cm_deep_M3_pred_high'] * df_copy['Fe3_m3'] 
#df_copy["pw_flux_doc_pred_hypox"] =  64.7129  + -0.1950 * df_copy['Fe2_m3'] + -2.3015 * df_copy['OCkg_5cm_deep_M3_pred'] + -0.3396 * df_copy['O2_uM_bottom'] / multiplyer + 0.0135 * df_copy['OCkg_5cm_deep_M3_pred'] * df_copy['O2_uM_bottom'] / multiplyer + 0.0053 * df_copy['OCkg_5cm_deep_M3_pred'] * df_copy['Fe3_m3'] 
#df_copy["pw_flux_doc_pred_climate_change"] =  64.7129  + -0.1950 * df_copy['Fe2_m3'] + -2.3015 * df_copy['OCkg_5cm_deep_M3_pred_high'] + -0.3396 * df_copy['O2_uM_bottom'] / multiplyer + 0.0135 * df_copy['OCkg_5cm_deep_M3_pred_high'] * df_copy['O2_uM_bottom'] / multiplyer + 0.0053 * df_copy['OCkg_5cm_deep_M3_pred_high'] * df_copy['Fe3_m3'] 

df_copy["pw_flux_doc_pred"] = 7.7701 + -0.4539 * df_copy['Fe2_m3_top'] + -0.5259 * df_copy['OCkg_5cm_deep_M3'] + 0.0206 * df_copy['OCkg_5cm_deep_M3'] * df_copy['Fe2_m3_top'] + 0.1352 * df_copy['O2_uM_bottom'] + 0.1458 * df_copy['NPOC_uM_bottom_water'] + -0.0015 * df_copy['O2_uM_bottom'] * df_copy['NPOC_uM_bottom_water'] 
df_copy["pw_flux_doc_pred_om"] = 7.7701 + -0.4539 * df_copy['Fe2_m3_top'] + -0.5259 * df_copy['OCkg_5cm_deep_M3_pred'] + 0.0206 * df_copy['OCkg_5cm_deep_M3_pred'] * df_copy['Fe2_m3_top'] + 0.1352 * df_copy['O2_uM_bottom'] + 0.1458 * df_copy['NPOC_uM_bottom_water'] + -0.0015 * df_copy['O2_uM_bottom'] * df_copy['NPOC_uM_bottom_water'] 
df_copy["pw_flux_doc_pred_precip"] = 7.7701 + -0.4539 * df_copy['Fe2_m3_top'] + -0.5259 * df_copy['OCkg_5cm_deep_M3_pred_high'] + 0.0206 * df_copy['OCkg_5cm_deep_M3_pred_high'] * df_copy['Fe2_m3_top'] + 0.1352 * df_copy['O2_uM_bottom'] + 0.1458 * df_copy['NPOC_uM_bottom_water'] + -0.0015 * df_copy['O2_uM_bottom'] * df_copy['NPOC_uM_bottom_water'] 
df_copy["pw_flux_doc_pred_hypox"] = 7.7701 + -0.4539 * df_copy['Fe2_m3_top'] + -0.5259 * df_copy['OCkg_5cm_deep_M3_pred'] + 0.0206 * df_copy['OCkg_5cm_deep_M3_pred'] * df_copy['Fe2_m3_top'] + 0.1352 * (df_copy['O2_uM_bottom']/multiplyer) + 0.1458 * df_copy['NPOC_uM_bottom_water'] + -0.0015 * (df_copy['O2_uM_bottom']/multiplyer) * df_copy['NPOC_uM_bottom_water'] 
df_copy["pw_flux_doc_pred_climate_change"] = 7.7701 + -0.4539 * df_copy['Fe2_m3_top'] + -0.5259 * df_copy['OCkg_5cm_deep_M3_pred_high'] + 0.0206 * df_copy['OCkg_5cm_deep_M3_pred_high'] * df_copy['Fe2_m3_top'] + 0.1352 * (df_copy['O2_uM_bottom']/multiplyer) + 0.1458 * df_copy['NPOC_uM_bottom_water'] + -0.0015 * (df_copy['O2_uM_bottom']/multiplyer) * df_copy['NPOC_uM_bottom_water'] 
    
    
# Create a boxplot for pw_flux_doc
plt.figure(figsize=(2, 4))
sns.boxplot(y=df_copy['pw_flux_doc'], color='white', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
sns.stripplot(y=df_copy['pw_flux_doc'], color='white', jitter=0.2, size=7.5, linewidth=1.75, edgecolor='black')
plt.title('Sediment DOC Flux')
plt.ylabel(r'F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
plt.ylim(0,20)
plt.show()

plt.figure(figsize=(2, 4))
sns.boxplot(y=df_copy['OCkg_5cm_deep_M3'], color='white', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
sns.stripplot(y=df_copy['OCkg_5cm_deep_M3'], color='white', jitter=0.2, size=7.5, linewidth=1.75, edgecolor='black')
plt.title(r'Sediment C$_{org}$')
plt.ylabel(r'C$_{org}$ inventory $(kg$ $m^{-3})$')
plt.ylim(12,45)
plt.show()

#######################

plt.figure(figsize=(2, 4))
sns.boxplot(y=df_copy['pw_flux_doc_pred'], color='gray', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
sns.stripplot(y=df_copy['pw_flux_doc_pred'], color='white', jitter=0.2, size=7.5, linewidth=1.75, edgecolor='black')
plt.title('DOC Flux Model')
plt.ylabel(r'F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
plt.ylim(0,20)
plt.show()

plt.figure(figsize=(2, 4))
sns.boxplot(y=df_copy['pw_flux_doc_pred_om'], color='gray', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
sns.stripplot(y=df_copy['pw_flux_doc_pred_om'], color='white', jitter=0.2, size=7.5, linewidth=1.75, edgecolor='black')
plt.title('DOC Flux Model'+'\n'+ 'OC predicted')
plt.ylabel(r'F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
plt.ylim(0,20)
plt.show()

plt.figure(figsize=(2, 4))
sns.boxplot(y=df_copy['OCkg_5cm_deep_M3_pred'], color='gray', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
sns.stripplot(y=df_copy['OCkg_5cm_deep_M3_pred'], color='white', jitter=0.2, size=7.5, linewidth=1.75, edgecolor='black')
plt.title(r'Sediment C$_{org}$ Model')
plt.ylabel(r'C$_{org}$ inventory $(kg$ $m^{-3})$')
plt.ylim(12,45)
plt.show()

####################

plt.figure(figsize=(2, 4))
sns.boxplot(y=df_copy['pw_flux_doc_pred_hypox'], color='red', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
sns.stripplot(y=df_copy['pw_flux_doc_pred_hypox'], color='white', jitter=0.2, size=7.5, linewidth=1.75, edgecolor='black')
plt.title('DOC Flux model lowerd O2')
plt.ylabel(r'F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
plt.ylim(0,20)
plt.show()

####################

plt.figure(figsize=(2, 4))
sns.boxplot(y=df_copy['pw_flux_doc_pred_precip'], color='blue', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
sns.stripplot(y=df_copy['pw_flux_doc_pred_precip'], color='white', jitter=0.2, size=7.5, linewidth=1.75, edgecolor='black')
plt.title('DOC Flux Model \n Raised River Inputs')
plt.ylabel(r'F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
plt.ylim(0,20)
plt.show


plt.figure(figsize=(2, 4))
sns.boxplot(y=df_copy['OCkg_5cm_deep_M3_pred_high'], color='blue', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
sns.stripplot(y=df_copy['OCkg_5cm_deep_M3_pred_high'], color='white', jitter=0.2, size=7.5, linewidth=1.75, edgecolor='black')
plt.title(r'Sediment C$_{org}$ Model' +'\n'+ 'Raised River Inputs')
plt.ylabel(r'C$_{org}$ inventory $(kg$ $m^{-3})$')
plt.ylim(12,45)
plt.show()

####################

plt.figure(figsize=(2, 4))
sns.boxplot(y=df_copy['pw_flux_doc_pred_climate_change'], color='green', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
sns.stripplot(y=df_copy['pw_flux_doc_pred_climate_change'], color='white', jitter=0.2, size=7.5, linewidth=1.75, edgecolor='black')
plt.title('DOC Flux model Future Senario')
plt.ylabel(r'F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
plt.ylim(0,20)
plt.show()

print('DOC flux Mean:', df_copy['pw_flux_doc'].mean())
print('DOC flux Mean Model:', df_copy['pw_flux_doc_pred'].mean())
print('DOC flux Mean Model with modled OC:', df_copy['pw_flux_doc_pred_om'].mean())
print('DOC flux Mean Precitation increased:', df_copy['pw_flux_doc_pred_precip'].mean())
print('DOC flux Mean Oxygen lowerd:', df_copy['pw_flux_doc_pred_hypox'].mean())
print('DOC flux Mean Climate Change:', df_copy['pw_flux_doc_pred_climate_change'].mean())


print('OM Mean:', df_copy['OCkg_5cm_deep_M3'].mean())
print('OM Mean Model:', df_copy['OCkg_5cm_deep_M3_pred'].mean())
print('OM Mean Precitation increased:', df_copy['OCkg_5cm_deep_M3_pred_high'].mean())
# Out:
# DOC flux Mean: 9.481447719314774
# DOC flux Mean Model: 19.66387028061944
# DOC flux Mean Model with modled OC: 5.645257556863183
# DOC flux Mean Precitation increased: 5.132309086197955
# DOC flux Mean Oxygen lowerd: 5.541165395671838
# DOC flux Mean Climate Change: 5.028216925006609
# OM Mean: 4.329932564568073
# OM Mean Model: 30.808286779474678
# OM Mean Precitation increased: 31.789977961858966

# %%
df_copy['season']
# Out:
# code
# St.11_GOM2021      summer
# St.13_GOM2021      summer
# St.14_GOM2021      summer
# St.15_GOM2021      summer
# St.16_GOM2021      summer
# St.2_GOM2021       summer
# St.4_GOM2021       summer
# St.5B_GOM2021      summer
# St.7_GOM2021       summer
# St.9_GOM2021       summer
# St.MK_GOM2021      summer
# St.ML_GOM2021      summer
# St.11_GOM21FA        fall
# St.12_GOM21FA        fall
# St.13_GOM21FA        fall
# St.14_GOM21FA        fall
# St.14.5_GOM21FA      fall
# St.15_GOM21FA        fall
# St.16_GOM21FA        fall
# St.16-2_GOM21FA      fall
# St.2_GOM21FA         fall
# St.4_GOM21FA         fall
# St.5B_GOM21FA        fall
# St.6_GOM21FA         fall
# St.7_GOM21FA         fall
# St.9_GOM21FA         fall
# St.MK_GOM21FA        fall
# St.MK-2_GOM21FA      fall
# St.13_GOM22SP      spring
# St.14_GOM22SP      spring
# St.15_GOM22SP      spring
# St.16_GOM22SP      spring
# St.2_GOM22SP       spring
# St.4_GOM22SP       spring
# St.5B_GOM22SP      spring
# ...

# %%
# Define custom colors and labels
color_map = {
    'summer': 'darkred',
    'spring': 'blue',
    'fall': 'green',
}

group_label_map_seas = {
    'summer': 'Summer',
    'spring': 'Spring',
    'fall': 'Fall',
}

color_map_rgn = {
    'hypox': '#FCEAEA',
    'riv': '#EAEEFC',
    'slope': '#ECFCEA',
    'shelf': '#F1EAFC'
}

group_label_map = {
    'riv': 'River Stations',
    'hypox': 'Hypoxic Shelf',
    'shelf': 'Non-Hypoxic Shelf',
    'slope': 'Slope'
}

variable_label_map = {
    'pw_flux_doc_pred_climate_change': r'F$_{DOC}$ '+'\n'+ r'(mmol $m^{-2}$ $day^{-1})$',
    'pw_flux_fe3': r'F$_{dFe(III)}$ '+'\n'+ r'(mmol $m^{-2}$ $day^{-1})$',
    'pw_flux_fe2': r'F$_{dFe(II)}$'+'\n'+ r'(mmol $m^{-2}$ $day^{-1})$',
    'pw_flux_tn': r'F$_{TDN}$ '+'\n'+ r'(mmol $m^{-2}$ $day^{-1})$',
}

variable_title_map = {
    'pw_flux_doc_pred_climate_change': r'Coastal Change Senario for Diffusive F$_{DOC}$',
    'pw_flux_fe3': 'Diffusive Flux'+'\n'+r'F$_{dFe(III)}$',
    'pw_flux_fe2': 'Diffusive Flux'+'\n'+ r'F$_{dFe(II)}$',
    'pw_flux_tn': 'Diffusive Flux'+'\n'+ r'F$_{TDN}$'
}

variable_limits = {
    'pw_flux_doc': (-1, 30), 
    'pw_flux_fe3': (-1, 5.25),
    'pw_flux_fe2': (-1, 5.25),
    'pw_flux_tn': (-1, 4)  # corrected the extra comma
}


var = 'pw_flux_doc_pred_climate_change'

# Create a boxplot for each variable in a subplot
fig, axes = plt.subplots(1, 1, figsize=(6, 6)) 

# Loop through variables and create boxplots
sns.boxplot(data=df_copy, x='rgn', y=var, palette=color_map_rgn, order=group_label_map.keys(), ax=axes,
            flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
sns.stripplot(data=df_copy, x='rgn', y=var, hue='season', jitter=0.25, order=group_label_map.keys(), ax=axes,
                size = 7.5, linewidth = 1.0, edgecolor = 'black', palette=color_map)
axes.set_title(variable_title_map[var])  # Set title
axes.set_xlabel("")  # Remove x-axis label
axes.set_ylabel(variable_label_map[var])  # Remove y-axis label
    
axes.set_xticklabels([group_label_map[x.get_text()] for x in axes.get_xticklabels()])

legend_handles = [Line2D([0], [0], marker='o', color='w', label=label, markerfacecolor=color, markersize=10) for label, color in color_map.items()]
axes.legend(title='', handles=legend_handles, labels=group_label_map_seas.values(), loc='lower left')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Assuming df is your DataFrame
# Fix the calculation of tt_y_C and tt_y_OC
df_copy['tt_y_OC'] = (df_copy['OCkg_5cm_deep_M3']* 1000 / 12.011) / (df_copy['pw_flux_doc'] * 365 / 1000)

df_copy['tt_y_OC_sen'] = (df_copy['OCkg_5cm_deep_M3_pred_high'] *1000 / 12.011) / (df_copy['pw_flux_doc_pred_climate_change'] * 365 / 1000)

categories = ['St.5B', 'St.7', 'St.2', 'St.9', 'St.14', 'St.11']
subcategories = ['GOM21FA', 'GOM22SP', 'GOM22SU']

def bar_plot_stock(data_f, flux_col, ylabels, title): 
    df = data_f.dropna(subset=[flux_col])

    color_map = {
        'GOM2021': 'darkred',
        'GOM21FA': 'blue',
        'GOM22SP': 'green',
        'GOM22SU': 'purple'
    }

    label_map = {
        'GOM2021': 'Summer 2021',
        'GOM21FA': 'Fall 2021',
        'GOM22SP': 'Spring 2022',
        'GOM22SU': 'Summer 2022'
    }

    barWidth = 0.25
    fig, ax = plt.subplots(figsize=(10, 5))

    # Adjusted r for spacing between groups
    r = np.arange(0, len(categories) * 1.2, 1.2)
    positions = [r + i * barWidth for i in range(len(subcategories))]

    for pos, subcat in zip(positions, subcategories):
        values = []
        errors = []
        for cat in categories:
            value = df[(df['Stn'] == cat) & (df['Camp'] == subcat)][flux_col].values
            if len(value) > 0:
                values.append(value[0])
            else:
                values.append(np.nan)  # Append NaN for missing values
            # Calculate errors, if needed
            # errors.append(YourErrorCalculationHere)

        ax.bar(pos, [v if v > 0 else 0 for v in values], width=barWidth, color=color_map[subcat],
               label=label_map[subcat])

    ax.set_ylim(0, df[flux_col].max() * 1.1)
    ax.set_xlabel('Stations: East to West              Stations: North to South', size=15)
    ax.set_ylabel(ylabels, size=15)
    ax.set_title(title, size=15)
    ax.set_xticks(r + 1*barWidth)
    ax.set_xticklabels(categories, size = 12)

    handles, _ = plt.gca().get_legend_handles_labels()
    labels = [label_map[subcat] for subcat in subcategories]
    ax.legend(handles[:len(subcategories)], labels)

    fig.set_facecolor('w')
    plt.tight_layout()

    plt.show()
    
    
def bar_plot_stock_2(data_f, flux_col, ylabes, tlabes): 
    df = data_f.dropna(subset=[flux_col])

    # Define custom colors
    color_map = {
        'GOM2021': 'darkred',
        'GOM21FA': 'blue',
        'GOM22SP': 'green',
        'GOM22SU': 'purple'
    }

    label_map = {
        'GOM2021': 'Summer 2021',
        'GOM21FA': 'Fall 2021',
        'GOM22SP': 'Spring 2022',
        'GOM22SU': 'Summer 2022'
    }

    barWidth = 0.25

    fig = plt.figure(figsize=(10, 5))
    gs = gridspec.GridSpec(2, 1, height_ratios=[5, 1], hspace=0)  # Set hspace to 0

    ax1 = plt.subplot(gs[0])
    ax2 = plt.subplot(gs[1])

    # Adjusted r for spacing between groups
    r = np.arange(0, len(categories) * 1.2, 1.2)
    positions = [r + i*barWidth for i in range(len(subcategories))]

    for pos, subcat in zip(positions, subcategories):
        values = []
        errors = []
        for cat in categories:
            value = df[(df['Stn'] == cat) & (df['Camp'] == subcat)][flux_col].values
            #error = df[(df['Stn'] == cat) & (df['Camp'] == subcat)]['erros_doc'].values
            values.append(value[0] if len(value) > 0 else 0)
            #errors.append(error[0] if len(error) > 0 else 0)
    
        ax1.bar(pos, [v if v > 0 else 0 for v in values], width=barWidth, color=color_map[subcat],
                label=label_map[subcat])#, yerr=[e if e > 0 else 0 for e in errors])
        ax2.bar(pos, [v if v < 0 else 0 for v in values], width=barWidth, color=color_map[subcat],
                label=label_map[subcat])#, yerr=[e if e > 0 else 0 for e in errors])
    
    ax1.set_ylim(0, df[flux_col].max()*1.1)  
    ax2.set_ylim(df[flux_col].min()*1.1, 0)

    ax1.spines['bottom'].set_visible(False)
    ax2.spines['top'].set_visible(False)
    ax1.xaxis.tick_top()
    ax1.tick_params(labeltop='off')
    ax2.xaxis.tick_bottom()

    # Add some text for labels, title, and custom x-axis tick labels
    ax2.set_xlabel('Stations: East to West              Stations: North to South', size = 15)
    ax1.set_ylabel(ylabes, size = 15)
    ax1.set_title(tlabes, size = 15)
    ax2.set_xticks(r + 1*barWidth)  # Adjust for the spaces between groups
    ax2.set_xticklabels(categories, size = 12)

    # Add black horizontal line at y=0
    ax1.axhline(0, color="black", linewidth=0.5)
    ax2.axhline(0, color="black", linewidth=0.5)

    handles, _ = plt.gca().get_legend_handles_labels()
    labels = [label_map[subcat] for subcat in subcategories]
    ax1.legend(handles[:len(subcategories)], labels)

    fig.set_facecolor('w')
    plt.tight_layout()

    plt.show()
    
    

ylabes = r'Future Senario Organic Carbon'+'\n'+'Turnover Time'+'\n'+ 'first 5 (cm)'+'\n'+r'years'
tlabes = 'Organic Carbon Turnover Time: first 5 (cm)'
data_f = df_copy
flux_col = "tt_y_OC_sen"

bar_plot_stock(data_f, flux_col, ylabes, tlabes) 

ylabes = r'Organic Carbon'+'\n'+'Turnover Time years'+'\n'+ 'first 5 (cm)'
tlabes = 'Organic Carbon Turnover Time: first 5 (cm)'
data_f = df_copy
flux_col = "tt_y_OC"

bar_plot_stock(data_f, flux_col, ylabes, tlabes)

# %%
ylabes = 'DOC flux sim'
tlabes = 'DOC flux sim'
data_f = df_copy
flux_col = "pw_flux_doc_pred_climate_change"
bar_plot_stock(data_f, flux_col, ylabes, tlabes) 

ylabes = 'DOC flux'
tlabes = 'DOC flux'
data_f = df_copy
flux_col = "pw_flux_doc"
bar_plot_stock(data_f, flux_col, ylabes, tlabes) 

ylabes = 'OC sim'
tlabes = 'OC sim'
data_f = df_copy
flux_col = "OCkg_5cm_deep_M3_pred"
bar_plot_stock(data_f, flux_col, ylabes, tlabes) 

ylabes = 'OM'
tlabes = 'OM' 
data_f = df_copy
flux_col = "OCkg_5cm_deep_M3"
bar_plot_stock(data_f, flux_col, ylabes, tlabes)

# %%
df_copy['pw_flux_doc_pred_climate_change']
#df_copy['OCkg_5cm_deep_M3_pred_high']
# Out:
# code
# St.11_GOM2021       4.645710
# St.13_GOM2021            NaN
# St.14_GOM2021       4.693390
# St.15_GOM2021       8.286723
# St.16_GOM2021       0.976977
# St.2_GOM2021        3.878417
# St.4_GOM2021        4.658452
# St.5B_GOM2021       0.690810
# St.7_GOM2021        4.101928
# St.9_GOM2021        4.320771
# St.MK_GOM2021       4.569684
# St.ML_GOM2021            NaN
# St.11_GOM21FA      13.449070
# St.12_GOM21FA      16.319507
# St.13_GOM21FA       6.742565
# St.14_GOM21FA       4.642985
# St.14.5_GOM21FA          NaN
# St.15_GOM21FA       7.418893
# St.16_GOM21FA       3.603148
# St.16-2_GOM21FA          NaN
# St.2_GOM21FA        5.156797
# St.4_GOM21FA        3.249840
# St.5B_GOM21FA       1.930551
# St.6_GOM21FA             NaN
# St.7_GOM21FA        5.438047
# St.9_GOM21FA        4.634853
# St.MK_GOM21FA       6.757601
# St.MK-2_GOM21FA          NaN
# St.13_GOM22SP            NaN
# St.14_GOM22SP      -1.901507
# St.15_GOM22SP            NaN
# St.16_GOM22SP            NaN
# ...

# %% [markdown]
# df_copy = df
# df_copy_2 = df
# df_copy.columns
#
# formula = 'OCkg_5cm_deep_M3 ~ discharge_mi_ftps_seven_day + discharge_af_ftps_seven_day + distance_to_af_lon_km + distance_to_delta_km + temp_surface + Max_pressure'
# model = sm.formula.ols(formula=formula, data=df_copy).fit()
# predicted = model.predict(df_copy)
# df_copy['OCkg_5cm_deep_M3_pred'] = predicted
#
# df_hypox = df_copy
#
# #df_hypox['O2_uM_bottom'] = df_hypox['O2_uM_bottom']
#
# formula = 'pw_flux_doc ~ OCkg_5cm_deep_M3_pred * O2_uM_bottom * Fe2_m3 * Fe3_m3'
# model = sm.formula.ols(formula=formula, data=df_copy).fit()
#
# predicted = model.predict(df_hypox)
# df_hypox['pw_flux_doc_pred'] = predicted
#
# predicted = model.predict(df_copy)
# df_copy['pw_flux_doc_pred'] = predicted
#
# # Define new formula for the second model
# formula_2 = 'pw_flux_doc ~ OCkg_5cm_deep_M3_pred * O2_uM_bottom * Fe2_m3 * Fe3_m3'
#
# # Fit the second model
# model_2 = sm.formula.ols(formula=formula_2, data=df_copy).fit()
#
# # Predicted values for the original and adjusted inputs
# predicted_original_2 = model_2.predict(df_copy)
# df_copy['pw_flux_doc_pred'] = predicted_original_2
#
# predicted_adjusted_2 = model_2.predict(df_percep)
# df_percep['pw_flux_doc_pred'] = predicted_adjusted_2
#
# # Plot predicted vs. real data for OCkg_5cm_deep_M3
# plt.figure(figsize=(10, 6))
# sns.boxplot(y='OCkg_5cm_deep_M3', data=df_copy, color='white', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
# sns.stripplot(y='OCkg_5cm_deep_M3_pred', data=df_copy, color='gray', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# sns.stripplot(y='OCkg_5cm_deep_M3', data=df_percep, color='blue', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# plt.title('Original vs. Adjusted Predictions for OCkg_5cm_deep_M3')
# plt.ylabel('OCkg_5cm_deep_M3')
# plt.show()
#
# # Plot predicted vs. real data for pw_flux_doc
# plt.figure(figsize=(10, 6))
# sns.boxplot(y='pw_flux_doc', data=df_copy, color='white', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
# sns.stripplot(y='pw_flux_doc_pred', data=df_copy, color='gray', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# sns.stripplot(y='pw_flux_doc', data=df_percep, color='blue', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# plt.title('Original vs. Adjusted Predictions for pw_flux_doc')
# plt.ylabel(r'F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
# plt.show()

# %% [markdown]
# # Assuming df_copy_2 is your original dataframe
# df_percep = df_copy_2.copy()
# df_2 = df_copy_2.dropna(subset=['OCkg_5cm_deep_M3'])
#
# # Adjust input values
# input_scaling_factor = 1.1
# df_percep['discharge_mi_ftps_seven_day'] *= input_scaling_factor
# df_percep['discharge_af_ftps_seven_day'] *= input_scaling_factor
#
# # Define model formula
# formula = 'OCkg_5cm_deep_M3 ~ discharge_mi_ftps_seven_day + discharge_af_ftps_seven_day + distance_to_af_lon_km + distance_to_delta_km + temp_surface + Max_pressure'
#
# # Fit the model
# model = sm.formula.ols(formula=formula, data=df_copy_2).fit()
#
# # Predicted values for the original and adjusted inputs
# predicted_original = model.predict(df_copy_2)
# df_copy_2['OCkg_5cm_deep_M3_pred'] = predicted_original
#
# predicted_adjusted = model.predict(df_percep)
# df_percep['OCkg_5cm_deep_M3_pred'] = predicted_adjusted
#
# # Plot predicted vs. real data
# plt.figure(figsize=(10, 6))
# sns.boxplot(y='OCkg_5cm_deep_M3', data=df_copy_2, color='white', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
# sns.stripplot(y='OCkg_5cm_deep_M3_pred', data=df_copy_2, color='gray', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# sns.stripplot(y='OCkg_5cm_deep_M3', data=df_copy_2, color='blue', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# plt.title('Original vs. Adjusted Predictions')
# plt.ylabel('OCkg_5cm_deep_M3')
# plt.show()
#
# # Define new formula for the next model
# formula = 'pw_flux_doc ~ OCkg_5cm_deep_M3_pred * O2_uM_bottom * Fe2_m3 * Fe3_m3'
#
# # Fit the new model
# model = sm.formula.ols(formula=formula, data=df_copy_2).fit()
#
# # Predicted values for the original and adjusted inputs
# predicted_original = model.predict(df_copy_2)
# df_copy_2['pw_flux_doc_pred'] = predicted_original
#
# predicted_adjusted = model.predict(df_percep)
# df_percep['pw_flux_doc_pred'] = predicted_adjusted
#
# # Plot predicted vs. real data for pw_flux_doc
# plt.figure(figsize=(10, 6))
# sns.boxplot(y='pw_flux_doc', data=df_copy_2, color='white', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
# sns.stripplot(y='pw_flux_doc_pred', data=df_copy_2, color='gray', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# sns.stripplot(y='pw_flux_doc', data=df_percep, color='blue', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# plt.title('Original vs. Adjusted Predictions for pw_flux_doc')
# plt.ylabel('pw_flux_doc')
# plt.show()

# %% [markdown]
# # Assuming df_copy_2 is your original dataframe
# df_percep = df_copy_2.copy()
# df_2 = df_copy_2.dropna(subset=['OCkg_5cm_deep_M3'])
#
# # Adjust input values
# input_scaling_factor = 1.1
# df_percep['discharge_mi_ftps_seven_day'] *= input_scaling_factor
# df_percep['discharge_af_ftps_seven_day'] *= input_scaling_factor
#
# # Define model formula
# formula_1 = 'OCkg_5cm_deep_M3 ~ discharge_mi_ftps_seven_day + discharge_af_ftps_seven_day + distance_to_af_lon_km + distance_to_delta_km + temp_surface + Max_pressure'
#
# # Fit the first model
# model_1 = sm.formula.ols(formula=formula_1, data=df_copy_2).fit()
#
# # Predicted values for the original and adjusted inputs
# predicted_original_1 = model_1.predict(df_copy_2)
# df_copy_2['OCkg_5cm_deep_M3_pred'] = predicted_original_1
#
# predicted_adjusted_1 = model_1.predict(df_percep)
# df_percep['OCkg_5cm_deep_M3_pred'] = predicted_adjusted_1
#
# # Define new formula for the second model
# formula_2 = 'pw_flux_doc ~ OCkg_5cm_deep_M3_pred * O2_uM_bottom * Fe2_m3 * Fe3_m3'
#
# # Fit the second model
# model_2 = sm.formula.ols(formula=formula_2, data=df_copy_2).fit()
#
# # Predicted values for the original and adjusted inputs
# predicted_original_2 = model_2.predict(df_copy_2)
# df_copy_2['pw_flux_doc_pred'] = predicted_original_2
#
# predicted_adjusted_2 = model_2.predict(df_percep)
# df_percep['pw_flux_doc_pred'] = predicted_adjusted_2
#
# plt.figure(figsize=(2, 4))
# sns.boxplot(y=df_copy_2['pw_flux_doc_pred'], color='gray', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
# sns.stripplot(y=df_copy_2['pw_flux_doc_pred'], color='white', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# plt.title('DOC Flux model')
# plt.ylabel(r'F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
# plt.ylim(0,20)
# plt.show()
#
# plt.figure(figsize=(2, 4))
# sns.boxplot(y=df_percep['pw_flux_doc_pred'], color='blue', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
# sns.stripplot(y=df_percep['pw_flux_doc_pred'], color='white', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# plt.title('DOC Flux model Incrased river inputs')
# plt.ylabel(r'F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
# #plt.ylim(0,20)
# plt.show()
#
# # Create a boxplot for pw_flux_doc
# plt.figure(figsize=(2, 4))
# sns.boxplot(y=df_copy_2['pw_flux_doc'], color='white', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
# sns.stripplot(y=df_copy_2['pw_flux_doc'], color='white', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# plt.title('Sediment Profile DOC Flux')
# plt.ylabel(r'F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
# plt.ylim(0,20)
# plt.show()

# %% [markdown]
# formula = 'OCkg_5cm_deep_M3 ~ discharge_mi_ftps_seven_day + discharge_af_ftps_seven_day + distance_to_af_lon_km + distance_to_delta_km + temp_surface + Max_pressure'
# model = sm.formula.ols(formula=formula, data=df_copy).fit()
# predicted = model.predict(df_copy)
# df_copy['OCkg_5cm_deep_M3_pred'] = predicted
#
# df_hypox = df_copy
#
# df_hypox['O2_uM_bottom'] = df_hypox['O2_uM_bottom']/1.5
#
# formula = 'pw_flux_doc ~ OCkg_5cm_deep_M3_pred * O2_uM_bottom * Fe2_m3 * Fe3_m3'
# model = sm.formula.ols(formula=formula, data=df_copy).fit()
#
# predicted = model.predict(df_hypox)
# df_hypox['pw_flux_doc_pred'] = predicted
#
# predicted = model.predict(df_copy)
# df_copy['pw_flux_doc_pred'] = predicted
#
# # Create a boxplot for pw_flux_doc
# plt.figure(figsize=(2, 4))
# sns.boxplot(y=df_copy['pw_flux_doc'], color='white', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
# sns.stripplot(y=df_copy['pw_flux_doc'], color='white', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# plt.title('Sediment Profile DOC Flux')
# plt.ylabel(r'F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
# plt.ylim(0,20)
# plt.show()
#
# plt.figure(figsize=(2, 4))
# sns.boxplot(y=df_copy['pw_flux_doc_pred'], color='gray', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
# sns.stripplot(y=df_copy['pw_flux_doc_pred'], color='white', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# plt.title('DOC Flux model')
# plt.ylabel(r'F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
# plt.ylim(0,20)
# plt.show()
#
# plt.figure(figsize=(2, 4))
# sns.boxplot(y=df_hypox['pw_flux_doc_pred'], color='red', flierprops={"markerfacecolor": "white", "markeredgecolor": "white"})
# sns.stripplot(y=df_hypox['pw_flux_doc_pred'], color='white', jitter=0.25, size=7.5, linewidth=1.75, edgecolor='black')
# plt.title('DOC Flux model lowerd O2')
# plt.ylabel(r'F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
# #lt.ylim(0,20)
# plt.show()

# %% [markdown]
# #df_t = df.drop('St.16_GOM21FA')
# df_t = df
#
# # Define the formula for linear regression
# formula = 'pw_flux_doc ~ OCkg_5cm_deep_M3 * max_depth * distance_to_delta_lon_km + discharge_mi_ftps + day_of_year + O2_uM_bottom'
#
#
# # Fit the linear regression model
# model = sm.formula.ols(formula=formula, data=df_t).fit()
# print(model.summary())
#
# # Extract coefficients and corresponding variables
# coefficients = model.params
# variables = coefficients.index.tolist()
#
# # Print out the equation nicely
# print("pw_flux_doc =", end=" ")
# for i, (variable, coefficient) in enumerate(zip(variables, coefficients)):
#     if i != 0:
#         print("+", end=" ")
#     print(f"{coefficient:.4f} * {variable}", end=" ")
# print()
#
# # Residuals
# residuals = model.resid
#
# # Plot 1: Residuals vs Fitted values
# sns.residplot(x=model.fittedvalues, y=residuals, lowess=True, line_kws={'color': 'red', 'lw': 1})
# plt.title('Residuals vs Fitted')
# plt.xlabel('Fitted values')
# plt.ylabel('Residuals')
# plt.show()
#
# # Plot 2: QQ Plot
# sm.qqplot(residuals, line ='45')
# plt.title('QQ Plot')
# plt.xlabel('Theoretical Quantiles')
# plt.ylabel('Sample Quantiles')
# plt.show()
#
# # Plot 3: Scale-Location Plot
# sqrt_abs_standardized_resid = abs(residuals**0.5)
# sns.regplot(x=model.fittedvalues, y=sqrt_abs_standardized_resid, lowess=True, line_kws={'color': 'red', 'lw': 1})
# plt.title('Scale-Location Plot')
# plt.xlabel('Fitted values')
# plt.ylabel('Square root of absolute standardized residuals')
# plt.show()
#
# # Plot 4: Residuals vs Leverage Plot (Cook's distance)
# sm.graphics.plot_leverage_resid2(model)
# plt.title('Residuals vs Leverage')
# plt.xlabel('Leverage')
# plt.ylabel('Standardized Residuals')
# plt.show()
#
# # Make predictions
# predicted = model.predict(df_t)
#
# # Insert predictions back to dataframe
# df_t['pw_flux_doc_pred'] = predicted
#
# # Plot
# plt.scatter(df_t['pw_flux_doc'], predicted)
# plt.xlabel(r'Actual F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
# plt.ylabel(r'Predicted F$_{DOC}$ (mmol $m^{-2}$ $day^{-1})$')
# plt.title('Model of Internal Controls')
# plt.plot([0, df_t['pw_flux_doc'].max()],
#          [0, df_t['pw_flux_doc'].max()], 'r--')
# plt.show()
