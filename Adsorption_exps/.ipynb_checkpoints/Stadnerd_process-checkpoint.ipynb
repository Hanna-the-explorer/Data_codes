# %%
import pandas as pd #the csv reading library
import matplotlib.pyplot as plt #the ploting library
import glob #to get file names
import numpy as np
from pandas import Series
import seaborn as sns
from matplotlib.pyplot import figure
import cmocean.cm as cmo
import seaborn as sns

#LOAD REQUIERD PACKAGES 
import os # OS library 
import pandas as pd #the csv reading library 
import matplotlib.pyplot as plt #the ploting library 
import glob #to get file names 

from scipy.interpolate import PchipInterpolator # Interpolator 
import numpy as np 
from scipy.optimize import curve_fit 
from scipy.optimize import minimize 
import re

# %%
files = glob.glob(f'../../Dissertation_projects/Absorption_experiments/Data/UV_exps_hanna_method_30*/*Sample*.asc')
files
# Out:
# ['../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Monday, November 25, 2024 9_21 AM Eastern Standard Time\\Sample24.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Monday, November 25, 2024 9_21 AM Eastern Standard Time\\Sample25.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Monday, November 25, 2024 9_21 AM Eastern Standard Time\\Sample26.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Monday, November 25, 2024 9_21 AM Eastern Standard Time\\Sample27.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Monday, November 25, 2024 9_21 AM Eastern Standard Time\\Sample28.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Monday, November 25, 2024 9_21 AM Eastern Standard Time\\Sample29.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Monday, November 25, 2024 9_21 AM Eastern Standard Time\\Sample30.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Monday, November 25, 2024 9_21 AM Eastern Standard Time\\Sample31.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Monday, November 25, 2024 9_21 AM Eastern Standard Time\\Sample32.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Monday, November 25, 2024 9_21 AM Eastern Standard Time\\Sample33.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Monday, November 25, 2024 9_21 AM Eastern Standard Time\\Sample34.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Monday, November 25, 2024 9_21 AM Eastern Standard Time\\Sample35.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample10.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample11.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample12.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample13.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample14.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample15.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample16.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample17.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample18.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample19.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample20.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample21.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample22.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample23.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample6.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample7.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample8.Sample.Raw.asc',
#  '../../Dissertation_projects/Absorption_experiments/Data\\UV_exps_hanna_method_30_sec_resp_time Sunday, November 24, 2024 11_04 AM Eastern Standard Time\\Sample9.Sample.Raw.asc']

# %%
df = pd.read_table(files[0], skiprows=91,names=['wl', 'abs'], index_col='wl')


with open(files[3], 'r') as f:
        lines = f.readlines()
wl_line = lines[2].strip() 
wl_names = wl_line.split('.')
wl_names[0]
# Out:
# 'Sample27'

# %%
def open_files(name):
    # reads individual scan files
    df = pd.read_table(name, skiprows=91,names=['wl', 'abs'], index_col='wl')
    # reads individual scan files
    with open(name, 'r') as f:
        lines = f.readlines()
    wl_line = lines[2].strip() 
    wl_names = wl_line.split('.')
    ID = wl_names[0]
    df = df.rename(columns={'abs': ID})
    return df


#LOOP TRU FILES TO MAKE ONE EASY TO USE DATA FRAME 
#columns are scanns and rows are wavelths 
frames = [open_files(f) for f in files]
df = pd.concat(frames, axis=1) # joins along cols  

print("files loaded and the data frame is made")
df
# Out:
# files loaded and the data frame is made
#        Sample24  Sample25  Sample26  Sample27  Sample28  Sample29  Sample30  \
# wl
# 445.0  0.000062  0.000083  0.000078  0.000094  0.000085  0.000120  0.000080
# 440.0  0.000041  0.000052  0.000059  0.000072  0.000065  0.000050  0.000060
# 435.0  0.000007  0.000039  0.000013  0.000049  0.000027  0.000090  0.000066
# 430.0  0.000016  0.000036  0.000055  0.000033  0.000040  0.000067  0.000071
# 425.0  0.000052  0.000057  0.000054  0.000065  0.000073  0.000058  0.000052
# 420.0  0.000052  0.000056  0.000057  0.000044  0.000054  0.000101  0.000081
# 415.0  0.000063  0.000083  0.000078  0.000024  0.000064  0.000100  0.000084
# 410.0  0.000007  0.000025  0.000033  0.000028  0.000039  0.000050  0.000004
# 405.0  0.000046  0.000030  0.000064  0.000035  0.000038  0.000069  0.000070
# 400.0  0.000085  0.000065  0.000068  0.000016  0.000037  0.000047  0.000068
# 395.0  0.000024  0.000021 -0.000013  0.000008  0.000004 -0.000001  0.000026
# 390.0  0.000038  0.000014  0.000048  0.000045  0.000057  0.000041  0.000032
# 385.0  0.000070  0.000079  0.000100  0.000112  0.000096  0.000117  0.000141
# 380.0  0.000079  0.000098  0.000106  0.000064  0.000127  0.000131  0.000158
# 375.0  0.000093  0.000218  0.000191  0.000153  0.000052  0.000041  0.000126
# 370.0  0.000092  0.000073  0.000123  0.000121  0.000107  0.000105  0.000076
# 365.0  0.000019 -0.000037  0.000011  0.000003  0.000022  0.000063  0.000029
# 360.0  0.000076  0.000010  0.000069  0.000032  0.000146  0.000178  0.000047
# 355.0  0.000035  0.000115  0.000138  0.000092  0.000113  0.000163  0.000180
# 350.0 -0.000032  0.000120  0.000017  0.000097  0.000068  0.000053  0.000178
# 345.0  0.000054  0.000062  0.000069  0.000098  0.000047  0.000113  0.000098
# 340.0 -0.000026  0.000012  0.000002  0.000046  0.000012  0.000078  0.000067
# 335.0  0.000030  0.000087  0.000161  0.000111  0.000117  0.000146  0.000099
# 330.0  0.000070  0.000127  0.000126  0.000043  0.000099  0.000125  0.000109
# 325.0 -0.000060 -0.000085  0.000005  0.000051  0.000089  0.000016  0.000125
# 320.0  0.000070  0.000088  0.000028  0.000106 -0.000012  0.000106  0.000124
# 360.0  0.000015  0.000015  0.000050  0.000089  0.000031  0.000024  0.000019
# 355.0  0.000066  0.000020  0.000025 -0.000045  0.000122 -0.000035 -0.000018
# 350.0  0.000014 -0.000007  0.000051  0.000012  0.000069 -0.000021  0.000018
# 345.0  0.000028  0.000104  0.000047  0.000067  0.000095  0.000162  0.000087
# 340.0  0.000031  0.000038  0.000050  0.000050  0.000110  0.000042  0.000085
# 335.0  0.000043 -0.000001  0.000041 -0.000012  0.000014  0.000042  0.000031
# 330.0  0.000059  0.000140  0.000047  0.000038 -0.000032  0.000002 -0.000003
# 325.0  0.000146  0.000159  0.000170  0.000054  0.000081  0.000086  0.000084
# 320.0  0.000031  0.000082  0.000056  0.000068  0.000078  0.000101  0.000013
# 315.0  0.000129  0.000031  0.000078  0.000039  0.000036  0.000015  0.000021
# 310.0  0.000088  0.000120  0.000140  0.000171  0.000069  0.000076  0.000082
# 305.0  0.000157 -0.000003  0.000060  0.000047  0.000034  0.000071  0.000085
# 300.0  0.000075  0.000079  0.000135 -0.000021  0.000044  0.000062  0.000068
# 295.0  0.000112  0.000139  0.000102  0.000054  0.000011  0.000066  0.000042
# 290.0  0.000033  0.000044  0.000153  0.000105  0.000086  0.000121  0.000089
# 285.0  0.000169  0.000133  0.000054 -0.000026  0.000087  0.000040  0.000061
# 280.0 -0.000197 -0.000021 -0.000231 -0.000333 -0.000131 -0.000241 -0.000197
# 275.0 -0.000125 -0.000128 -0.000198 -0.000232 -0.000035 -0.000198 -0.000067
# 270.0  0.000132  0.000214  0.000132  0.000019  0.000138  0.000134 -0.000013
# 265.0 -0.000114  0.000040 -0.000138 -0.000138 -0.000112 -0.000067 -0.000222
# 260.0 -0.000240 -0.000064 -0.000336  0.000034  0.000116 -0.000033  0.000067
# 255.0  0.000016  0.000469  0.000104  0.000408  0.000220  0.000222  0.000156
# 250.0 -0.000583 -0.000141 -0.000069 -0.000444 -0.000322 -0.000230 -0.000396
#
# [40 rows x 30 columns]

# %%
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(8, 4)) 
df.plot(ax=axs)
axs.set_xlim(250,450)
axs.set_ylim(-0.0015,0.0015)
axs.set_xlabel("Wavelength")
axs.axhline(y=0.0005, color='black', linewidth=1)
axs.axhline(y=-0.0005, color='black', linewidth=1)
axs.set_ylabel("A")
axs.legend("")
axs.set_title("Absorbance Spectra 30 second Method")
plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/Abs_scanns_30_second.png")

# %%
df_abs = df*2.303/.1

# %%
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(8, 4)) 
df_abs.plot(ax=axs)
axs.set_xlim(250,450)
axs.set_ylim(-0.02,0.02)
axs.axhline(y=0, color='black', linewidth=.5)
#axs.axhline(y=-0.00035, color='black', linewidth=1)
axs.set_xlabel("Wavelength")
axs.set_ylabel("a (1/m)")
axs.legend("")
axs.set_title("Absorption Spectra 30 second Method")
plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/scanns_abs_30_second_mathod.png")

# %%
def JF2007_aw_UV(wl, T):
    """
    Parameters:
    wl : array-like or float
        Wavelength in nm, should be in the 180-420 nm range.
    T : float
        Temperature in degrees Celsius.
    
    Returns:
    a : array-like or float
        Combined absorption coefficient.
    a_QI_fit : array-like or float
        Quantum interference term of the absorption coefficient.
    a_GH_fit : array-like or float
        General harmonic term of the absorption coefficient.
    """
    
    # Convert wavelength to frequency in 1/cm
    v = (1 / 150 - 1 / wl) * 1e7
    
    # Convert temperature to Kelvin
    K = T + 273
    
    # Calculate Zc
    Zc = (v ** (11 / 12) / np.sqrt(K)) ** (2 / 3)
    
    # Calculate a_QI_fit from JF2007, Eq. 2.82
    a_QI_fit = 5e6 * v ** (-5 / 4) * np.exp(-0.076 * Zc)
    
    # Calculate a_GH_fit from JF2007, Eq. 2.78-2.79
    a_GH_fit = 7.067e-40 * np.exp(119 * 150 / (wl - (0.0465 * (T - 25))))
    
    # Calculate total absorption coefficient
    a = a_QI_fit + a_GH_fit
    
    return a, a_QI_fit, a_GH_fit


# this is the function to minimize the root mean squared 
def rmse(T, col_abs):
    cor = JF2007_aw_UV(wl, T)
    a = cor[0]
    col_resid = col_abs - a
    diff = np.sqrt(np.mean(col_resid**2))
    return  diff

# %%
## DO the TEMP correction ##

df_abs['wl'] = df_abs.index
df_abs_cut = df_abs[df_abs['wl'] <= 420]

####### OLD ###########
wl = df_abs_cut['wl'].to_numpy()
df_abs_cut = df_abs_cut.drop('wl', axis = 1)


coln = np.arange(0, len(df_abs_cut.columns), 1, dtype=int)
Frames = []
frames = []

for col in coln:
    col_abs = df_abs_cut.iloc[:,col].ravel()
    res = minimize(rmse, 0, col_abs) 
    temp_val = res.x[0]
    cor = JF2007_aw_UV(wl, res.x)
    a = cor[0]
    col_ct = col_abs - a
    col_ct_data_frame = pd.DataFrame(col_ct)
    Frames.append(col_ct_data_frame)
    col_ct_resid = col_ct-(df_abs_cut.iloc[:,col].ravel())
    temp_rmse = np.sqrt(np.mean(col_ct_resid**2))
    dict = {'temp_val':[temp_val], 
           'temp_rmse':[temp_rmse]}
    diff = pd.DataFrame(dict)
    frames.append(diff) #save the inportant outputs 

outputs = pd.concat(frames, axis=0, ignore_index=False)
New_Labels = df.columns
outputs.index = list(New_Labels)

df_temp_corrected = pd.concat(Frames, axis=1, ignore_index=False)
New_Labels = df.columns
df_temp_corrected.columns = New_Labels
df_temp_corrected['wl'] = wl
df_temp_corrected.index = df_temp_corrected['wl']
df_temp_corrected = df_temp_corrected.drop('wl', axis = 1)
df_tc = df_temp_corrected
df_temp_corrected
# Out:
# C:\Users\hmlbr\AppData\Local\Temp\ipykernel_28068\1436059240.py:16: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   col_abs = df_abs_cut.iloc[:,col].ravel()
# C:\Users\hmlbr\AppData\Local\Temp\ipykernel_28068\1436059240.py:24: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#
ig, axs = plt.subplots(nrows=1, ncols=1, figsize=(8, 4)) 
df_temp_corrected.plot(ax=axs)
axs.set_xlim(250,420)
axs.set_ylim(-0.02,0.02)
axs.axhline(y=0, color='black', linewidth=.5)
axs.set_xlabel("Wavelength")
axs.set_ylabel("a (1/m)")
axs.legend("")
axs.set_title("Absorbance Spectra old Method: Temp Corrected")
plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/Abs_scanns_temp_corr_30_second_meth.png")

# %%
# Define a function for RMSE
def calculate_rmse(values):
    return np.sqrt(np.mean(np.square(values)))

# Define a function for SEM
def calculate_sem(values):
    return np.std(values, ddof=1) / np.sqrt(len(values))

# Compute the statistics
new_df = pd.DataFrame({
    'mean': df_tc.apply(lambda row: row.mean(), axis=1),
    'min': df_tc.apply(lambda row: row.min(), axis=1),
    'max': df_tc.apply(lambda row: row.max(), axis=1),
    'rmse': df_tc.apply(lambda row: calculate_rmse(row), axis=1),
    'sem': df_tc.apply(lambda row: calculate_sem(row), axis=1)
})

new_df['rmse_up'] = new_df['mean'] + new_df['rmse']
new_df['rmse_down'] = new_df['mean'] - new_df['rmse']

new_df['sem_up'] = new_df['mean'] + new_df['sem']
new_df['sem_down'] = new_df['mean'] - new_df['sem']

new_df['range'] = new_df['max'] - new_df['min']


#Data_output_error_test_new_method_30_stats_tc
new_df.to_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_30_stats_tc.csv')
new_df
# Out:
#            mean       min       max      rmse       sem   rmse_up  rmse_down  \
# wl
# 420.0  0.001028 -0.000054  0.002210  0.001161  0.000100  0.002189  -0.000133
# 415.0  0.000962 -0.000355  0.002181  0.001166  0.000122  0.002128  -0.000204
# 410.0  0.001003 -0.000207  0.002229  0.001136  0.000099  0.002139  -0.000134
# 405.0  0.001050  0.000205  0.002150  0.001131  0.000078  0.002181  -0.000081
# 400.0  0.000807 -0.000592  0.002266  0.001096  0.000138  0.001903  -0.000289
# 395.0  0.000173 -0.001049  0.001002  0.000536  0.000094  0.000710  -0.000363
# 390.0  0.000463 -0.001032  0.001934  0.000778  0.000116  0.001241  -0.000315
# 385.0  0.001250 -0.000451  0.003519  0.001678  0.000208  0.002928  -0.000428
# 380.0  0.000975 -0.000822  0.003216  0.001511  0.000214  0.002486  -0.000537
# 375.0  0.000775 -0.002453  0.004891  0.002173  0.000377  0.002948  -0.001398
# 370.0  0.001169 -0.001646  0.002796  0.001595  0.000202  0.002764  -0.000426
# 365.0 -0.000245 -0.002141  0.001404  0.000854  0.000152  0.000609  -0.001099
# 360.0  0.001238 -0.001961  0.004005  0.001860  0.000258  0.003098  -0.000622
# 355.0  0.001509 -0.001083  0.005275  0.002185  0.000293  0.003695  -0.000676
# 350.0  0.000688 -0.002593  0.003459  0.001555  0.000259  0.002243  -0.000867
# 345.0  0.002058  0.000624  0.003704  0.002191  0.000140  0.004249  -0.000134
# 340.0  0.000772 -0.000648  0.002501  0.001067  0.000137  0.001838  -0.000295
# 335.0  0.001500 -0.001039  0.005509  0.002127  0.000280  0.003627  -0.000627
