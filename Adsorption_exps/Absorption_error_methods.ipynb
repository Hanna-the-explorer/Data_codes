# %%
import pandas as pd #the csv reading library
import matplotlib.pyplot as plt #the ploting library
import glob #to get file names
import numpy as np
from pandas import Series
import seaborn as sns
from matplotlib.pyplot import figure
import cmocean.cm as cmo
import seaborn as sns

# %%
df_new_3 = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_3.csv', sep=',', index_col=0)
df_new_2 = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_2.csv', sep=',', index_col=0)
df_old = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_old_method.csv', sep=',', index_col=0)

df_new_3_a = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_3_absorbance.csv', sep=',', index_col=0)
df_new_2_a = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_2_absorbance.csv', sep=',', index_col=0)
df_old_a = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_old_method_absorbance.csv', sep=',', index_col=0)

df_new_3_tcor = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_3_temp_cor.csv', sep=',', index_col=0)
df_new_2_tcor = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_2_temp_cor.csv', sep=',', index_col=0)
df_old_tcor = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_old_method_temp_cor.csv', sep=',', index_col=0)

df_new_3_stats = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_3_stats.csv')
df_new_2_stats = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_2_stats.csv')
df_old_stats = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_old_method_stats.csv')

df_new_3_range = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_3_range.csv')
df_new_2_range = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_2_range.csv')
df_old_range = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_old_method_range.csv')

df_new_3_stats_tc = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_3_stats_tc.csv')
df_new_2_stats_tc = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_2_stats_tc.csv')
df_old_stats_tc = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_old_method_stats_tc.csv')

# %%
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(8, 4)) 
df_old_a.plot(ax=axs)
axs.set_xlim(250,450)
axs.set_ylim(-0.0015,0.0015)
axs.set_xlabel("Wavelength")
axs.set_ylabel("A")
axs.axhline(y=0.0005, color='black', linewidth=1)
axs.axhline(y=-0.0005, color='black', linewidth=1)
axs.legend("")
axs.set_title("Absorbance Spectra old Method")
plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/scanns_absorb_old_meth.png")


fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(8, 4)) 
df_new_2_a.plot(ax=axs)
axs.set_xlim(250,450)
axs.set_ylim(-0.0015,0.0015)
axs.set_xlabel("Wavelength")
axs.set_ylabel("A")
axs.axhline(y=0.0005, color='black', linewidth=1)
axs.axhline(y=-0.0005, color='black', linewidth=1)
axs.legend("")
axs.set_title("Absorbance Spectra Method #2")
plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/scanns_absorb_new_meth_2.png")


fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(8, 4)) 
df_new_3_a.plot(ax=axs)
axs.set_xlim(250,450)
axs.set_ylim(-0.0015,0.0015)
axs.set_xlabel("Wavelength")
axs.axhline(y=0.0005, color='black', linewidth=1)
axs.axhline(y=-0.0005, color='black', linewidth=1)
axs.set_ylabel("A")
axs.legend("")
axs.set_title("Absorbance Spectra Method #3")
plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/scanns_absorb_new_meth_3.png")

# %%
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(8, 4)) 
df_old.plot(ax=axs)
axs.set_xlim(250,450)
axs.set_ylim(-0.05,0.05)
axs.set_xlabel("Wavelength")
axs.set_ylabel("a (1/m)")
axs.legend("")
axs.set_title("Absorption Spectra old Method")
plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/scanns_abs_old_meth.png")


fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(8, 4)) 
df_new_2.plot(ax=axs)
axs.set_xlim(250,450)
axs.set_ylim(-0.05,0.05)
axs.set_xlabel("Wavelength")
axs.set_ylabel("a (1/m)")
axs.legend("")
axs.set_title("Absorption Spectra new Method #2")
plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/scanns_abs_new_meth_2.png")


fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(8, 4)) 
df_new_3.plot(ax=axs)
axs.set_xlim(250,450)
axs.set_ylim(-0.05,0.05)
axs.set_xlabel("Wavelength")
axs.set_ylabel("a (1/m)")
axs.legend("")
axs.set_title("Absorption Spectra new Method #3")
plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/scanns_abs_new_meth_3.png")

# %%
fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(8, 4)) 
df_old_tcor.plot(ax=axs)
axs.set_xlim(250,420)
axs.set_ylim(-0.05,0.05)
axs.set_xlabel("Wavelength")
axs.set_ylabel("a (1/m)")
axs.legend("")
axs.set_title("Absorption Spectra Old Method: Temp Corrected")
plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/scanns_abs_old_meth_tcorr.png")


fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(8, 4)) 
df_new_2_tcor.plot(ax=axs)
axs.set_xlim(250,420)
axs.set_ylim(-0.05,0.05)
axs.set_xlabel("Wavelength")
axs.set_ylabel("a (1/m)")
axs.legend("")
axs.set_title("Absorption Spectra new Method #2: Temp Corrected")
plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/scanns_abs_new_meth_2_tcorr.png")


fig, axs = plt.subplots(nrows=1, ncols=1, figsize=(8, 4)) 
df_new_3_tcor.plot(ax=axs)
axs.set_xlim(250,420)
axs.set_ylim(-0.05,0.05)
axs.set_xlabel("Wavelength")
axs.set_ylabel("a (1/m)")
axs.legend("")
axs.set_title("Absorption Spectra new Method #3: Temp Corrected")
plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/scanns_abs_new_meth_3_tcorr.png")

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 3))

axes.plot(df_old_stats['wl'], df_old_stats['mean'], color='red', linewidth=1.5)
axes.plot(df_new_2_stats['wl'], df_new_2_stats['mean'], color='green', linewidth=1.5)
axes.plot(df_new_3_stats['wl'], df_new_3_stats['mean'], color='blue', linewidth=1.5)

axes.plot(df_old_stats['wl'], df_old_stats['rmse_up'], color='red', linewidth=.25)
axes.plot(df_new_2_stats['wl'], df_new_2_stats['rmse_up'], color='green', linewidth=.25)
axes.plot(df_new_3_stats['wl'], df_new_3_stats['rmse_up'], color='blue', linewidth=.25)

axes.plot(df_old_stats['wl'], df_old_stats['rmse_down'], color='red', linewidth=.25)
axes.plot(df_new_2_stats['wl'], df_new_2_stats['rmse_down'], color='green', linewidth=.25)
axes.plot(df_new_3_stats['wl'], df_new_3_stats['rmse_down'], color='blue', linewidth=.25)

axes.fill_between(df_old_stats['wl'], df_old_stats['rmse_up'], df_old_stats['rmse_down'], alpha=.2, linewidth=0, color='pink')
axes.fill_between(df_new_2_stats['wl'], df_new_2_stats['rmse_up'], df_new_2_stats['rmse_down'], alpha=.2, linewidth=0, color='lightgreen')
axes.fill_between(df_new_3_stats['wl'], df_new_3_stats['rmse_up'], df_new_3_stats['rmse_down'], alpha=.2, linewidth=0, color='lightblue')

axes.set_xlabel("Wavelength")
axes.set_ylabel("a (1/m)")
axes.set_xlim(250, 420)
axes.set_ylim(-0.03, 0.02)
axes.text(400, .012, 'Old Method', color='red')
axes.text(400, .009, 'New Method 2', color='green')
axes.text(400, .006, 'New Method 3', color='blue')
axs.axhline(y=0.00035, color='black', linewidth=1)
axs.axhline(y=0.00035, color='black', linewidth=1)
plt.title('Mean and RMSE')
plt.tight_layout()
#plt.legend()
plt.grid(axis='y')

plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/Mean_RMSE_methods.png")

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 3))

axes.plot(df_old_stats['wl'], df_old_stats['mean'], color='red', linewidth=1.5)
axes.plot(df_new_2_stats['wl'], df_new_2_stats['mean'], color='green', linewidth=1.5)
axes.plot(df_new_3_stats['wl'], df_new_3_stats['mean'], color='blue', linewidth=1.5)

axes.plot(df_old_stats['wl'], df_old_stats['sem_up'], color='red', linewidth=.25)
axes.plot(df_new_2_stats['wl'], df_new_2_stats['sem_up'], color='green', linewidth=.25)
axes.plot(df_new_3_stats['wl'], df_new_3_stats['sem_up'], color='blue', linewidth=.25)

axes.plot(df_old_stats['wl'], df_old_stats['sem_down'], color='red', linewidth=.25)
axes.plot(df_new_2_stats['wl'], df_new_2_stats['sem_down'], color='green', linewidth=.25)
axes.plot(df_new_3_stats['wl'], df_new_3_stats['sem_down'], color='blue', linewidth=.25)

axes.fill_between(df_old_stats['wl'], df_old_stats['sem_up'], df_old_stats['sem_down'], alpha=.2, linewidth=0, color='pink')
axes.fill_between(df_new_2_stats['wl'], df_new_2_stats['sem_up'], df_new_2_stats['sem_down'], alpha=.2, linewidth=0, color='lightgreen')
axes.fill_between(df_new_3_stats['wl'], df_new_3_stats['sem_up'], df_new_3_stats['sem_down'], alpha=.2, linewidth=0, color='lightblue')

axes.set_xlabel("Wavelength")
axes.set_ylabel("a (1/m)")
axes.set_xlim(250, 420)
axes.set_ylim(-0.01, 0.01)
axes.text(400, .006, 'Old Method', color='red')
axes.text(400, .0045, 'New Method 2', color='green')
axes.text(400, .003, 'New Method 3', color='blue')
plt.title('Mean and SEM')
plt.tight_layout()
#plt.legend()
plt.grid(axis='y')

plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/Mean_SEM_methods.png")

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 3))

axes.plot(df_old_stats['wl'], df_old_stats['mean'], color='red', linewidth=1.5)
axes.plot(df_new_2_stats['wl'], df_new_2_stats['mean'], color='green', linewidth=1.5)
axes.plot(df_new_3_stats['wl'], df_new_3_stats['mean'], color='blue', linewidth=1.5)

axes.plot(df_old_range['wl'], df_old_range['min'], color='red', linewidth=.25)
axes.plot(df_new_2_range['wl'], df_new_2_range['min'], color='green', linewidth=.25)
axes.plot(df_new_3_range['wl'], df_new_3_range['min'], color='blue', linewidth=.25)

axes.plot(df_old_range['wl'], df_old_range['max'], color='red', linewidth=.25)
axes.plot(df_new_2_range['wl'], df_new_2_range['max'], color='green', linewidth=.25)
axes.plot(df_new_3_range['wl'], df_new_3_range['max'], color='blue', linewidth=.25)

axes.fill_between(df_old_range['wl'], df_old_range['max'], df_old_range['min'], alpha=.2, linewidth=0, color='pink')
axes.fill_between(df_new_2_range['wl'], df_new_2_range['max'], df_new_2_range['min'], alpha=.2, linewidth=0, color='lightgreen')
axes.fill_between(df_new_3_range['wl'], df_new_3_range['max'], df_new_3_range['min'], alpha=.2, linewidth=0, color='lightblue')

axes.set_xlabel("Wavelength")
axes.set_ylabel("a (1/m)")
axes.set_xlim(250, 420)
axes.set_ylim(-.075, .04)
axes.text(320, .022, 'Old Method', color='red')
axes.text(340, .022, 'New Method #2', color='green')
axes.text(365, .022, 'New Method #3', color='blue')
plt.title('Range Of data')
plt.tight_layout()
#plt.legend()
plt.grid(axis='y')

plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/Mean_reange_methods.png")

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 3))

axes.plot(df_old_stats['wl'], df_old_stats['mean'], color='red', linewidth=1.5)
axes.plot(df_new_2_stats['wl'], df_new_2_stats['mean'], color='green', linewidth=1.5)
axes.plot(df_new_3_stats['wl'], df_new_3_stats['mean'], color='blue', linewidth=1.5)

axes.plot(df_old_range['wl'], df_old_range['min'], color='red', linewidth=.25)
axes.plot(df_new_2_range['wl'], df_new_2_range['min'], color='green', linewidth=.25)
axes.plot(df_new_3_range['wl'], df_new_3_range['min'], color='blue', linewidth=.25)

axes.plot(df_old_range['wl'], df_old_range['max'], color='red', linewidth=.25)
axes.plot(df_new_2_range['wl'], df_new_2_range['max'], color='green', linewidth=.25)
axes.plot(df_new_3_range['wl'], df_new_3_range['max'], color='blue', linewidth=.25)

axes.fill_between(df_old_range['wl'], df_old_range['max'], df_old_range['min'], alpha=.2, linewidth=0, color='pink')
axes.fill_between(df_new_2_range['wl'], df_new_2_range['max'], df_new_2_range['min'], alpha=.2, linewidth=0, color='lightgreen')
axes.fill_between(df_new_3_range['wl'], df_new_3_range['max'], df_new_3_range['min'], alpha=.2, linewidth=0, color='lightblue')

axes.set_xlabel("Wavelength")
axes.set_ylabel("a (1/m)")
axes.set_xlim(370, 420)
axes.set_ylim(-.012, .012)
axes.axhline(y=0.00035, color='black', linewidth=1.5)
axes.axhline(y=-0.00035, color='black', linewidth=1.5)
axes.text(400, .01, 'Old Method', color='red')
axes.text(400, .008, 'New Method #2', color='green')
axes.text(400, .006, 'New Method #3', color='blue')
axes.text(390, -.011, 'line assumes at least Sullivan 2006  35 PSU  ', color='black')
plt.title('Range Of data')
plt.tight_layout()
#plt.legend()
plt.grid(axis='y')

plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/Mean_reange_methods_close.png")

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 3))
axes.plot(df_old_stats['wl'], df_old_stats['sem'], color='red', linewidth=1.5)
axes.plot(df_new_2_stats['wl'], df_new_2_stats['sem'], color='green', linewidth=1.5)
axes.plot(df_new_3_stats['wl'], df_new_3_stats['sem'], color='blue', linewidth=1.5)

axes.set_xlabel("Wavelength")
axes.set_ylabel("a (1/m)")
axes.set_xlim(250, 420)
axes.set_ylim(0, 0.0035)
axes.axhline(y=0.00035, color='black', linewidth=2, linestyle = 'dotted')
axes.text(365, .0031, 'Old Method', color='red')
axes.text(365, .0026, 'New Method #2', color='green')
axes.text(365, .0021, 'New Method #3', color='blue')
plt.title('Standard Error ')
plt.tight_layout()

#plt.legend()
plt.grid(axis='y')

plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/SEM_methods.png")

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 3))
axes.plot(df_old_stats['wl'], df_old_stats['rmse'], color='red', linewidth=1.5)
axes.plot(df_new_2_stats['wl'], df_new_2_stats['rmse'], color='green', linewidth=1.5)
axes.plot(df_new_3_stats['wl'], df_new_3_stats['rmse'], color='blue', linewidth=1.5)

axes.set_xlabel("Wavelength")
axes.set_ylabel("a (1/m)")
axes.set_xlim(250, 420)
axes.set_ylim(0, 0.02)
axes.axhline(y=0.00035, color='black',  linewidth=2, linestyle = 'dotted')
axes.text(365, .0177, 'Old Method', color='red')
axes.text(365, .0157, 'New Method #2', color='green')
axes.text(365, .0137, 'New Method #3', color='blue')
plt.title('Root Mean Squared Error')
plt.tight_layout()

#plt.legend()
plt.grid(axis='y')

plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/RMSE_methods.png")

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 3))
axes.plot(df_old_range['wl'], df_old_range['range'], color='red', linewidth=1.5)
axes.plot(df_new_2_range['wl'], df_new_2_range['range'], color='green', linewidth=1.5)
axes.plot(df_new_3_range['wl'], df_new_3_range['range'], color='blue', linewidth=1.5)

axes.set_xlabel("Wavelength")
axes.set_ylabel("a (1/m)")
axes.set_xlim(250, 420)
axes.set_ylim(0, 0.08)
axes.axhline(y=0.00035, color='black',  linewidth=2, linestyle = 'dotted')
axes.text(365, .07, 'Old Method', color='red')
axes.text(365, .064, 'New Method #2', color='green')
axes.text(365, .058, 'New Method #3', color='blue')
plt.title('Range of Data')
plt.tight_layout()

#plt.legend()
plt.grid(axis='y')

plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/Range_methods.png")

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 3))
axes.plot(df_old_stats['wl'], df_old_stats['sem'], color='red', linewidth=1.5)
axes.plot(df_new_2_stats['wl'], df_new_2_stats['sem'], color='green', linewidth=1.5)
axes.plot(df_new_3_stats['wl'], df_new_3_stats['sem'], color='blue', linewidth=1.5)
axes.plot(df_old_stats_tc['wl'], df_old_stats_tc['sem'], color='pink', linewidth=1.5)
axes.plot(df_new_2_stats_tc['wl'], df_new_2_stats_tc['sem'], color='lightgreen', linewidth=1.5)
axes.plot(df_new_3_stats_tc['wl'], df_new_3_stats_tc['sem'], color='lightblue', linewidth=1.5)

axes.set_xlabel("Wavelength")
axes.set_ylabel("a (1/m)")
axes.set_xlim(250, 420)
axes.set_ylim(0, 0.0035)
axes.axhline(y=0.00035, color='black', linewidth=2, linestyle = 'dotted')
axes.text(340, .0031, 'Old Method', color='red')
axes.text(340, .0026, 'New Method #2', color='green')
axes.text(340, .0021, 'New Method #3', color='blue')
axes.text(365, .0031, 'Old Method Temp Corrected', color='pink')
axes.text(365, .0026, 'New Method #2  Temp Corrected', color='lightgreen')
axes.text(365, .0021, 'New Method #3  Temp Corrected', color='lightblue')
plt.title('Standard Error ')
plt.tight_layout()

#plt.legend()
plt.grid(axis='y')

plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/SEM_methods_temp_corr.png")

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 3))
axes.plot(df_old_stats['wl'], df_old_stats['rmse'], color='red', linewidth=1.5)
axes.plot(df_new_2_stats['wl'], df_new_2_stats['rmse'], color='green', linewidth=1.5)
axes.plot(df_new_3_stats['wl'], df_new_3_stats['rmse'], color='blue', linewidth=1.5)
axes.plot(df_old_stats_tc['wl'], df_old_stats_tc['rmse'], color='pink', linewidth=1.5)
axes.plot(df_new_2_stats_tc['wl'], df_new_2_stats_tc['rmse'], color='lightgreen', linewidth=1.5)
axes.plot(df_new_3_stats_tc['wl'], df_new_3_stats_tc['rmse'], color='lightblue', linewidth=1.5)

axes.set_xlabel("Wavelength")
axes.set_ylabel("a (1/m)")
axes.set_xlim(250, 420)
axes.set_ylim(0, 0.02)
axes.axhline(y=0.00035, color='black',  linewidth=2, linestyle = 'dotted')
axes.text(340, .0177, 'Old Method', color='red')
axes.text(340, .0157, 'New Method #2', color='green')
axes.text(340, .0137, 'New Method #3', color='blue')
axes.text(365, .0177, 'Old Method Temp Corrected', color='pink')
axes.text(365, .0157, 'New Method #2  Temp Corrected', color='lightgreen')
axes.text(365, .0137, 'New Method #3  Temp Corrected', color='lightblue')
plt.title('Root Mean Squared Error')
plt.tight_layout()

#plt.legend()
plt.grid(axis='y')

plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/RMSE_methods_temp_corr.png")

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12, 3))
axes.plot(df_old_range['wl'], df_old_range['range'], color='red', linewidth=1.5)
axes.plot(df_new_2_range['wl'], df_new_2_range['range'], color='green', linewidth=1.5)
axes.plot(df_new_3_range['wl'], df_new_3_range['range'], color='blue', linewidth=1.5)
axes.plot(df_old_stats_tc['wl'], df_old_stats_tc['range'], color='pink', linewidth=1.5)
axes.plot(df_new_2_stats_tc['wl'], df_new_2_stats_tc['range'], color='lightgreen', linewidth=1.5)
axes.plot(df_new_3_stats_tc['wl'], df_new_3_stats_tc['range'], color='lightblue', linewidth=1.5)

axes.set_xlabel("Wavelength")
axes.set_ylabel("a (1/m)")
axes.set_xlim(250, 420)
axes.set_ylim(0, 0.08)
axes.axhline(y=0.00035, color='black',  linewidth=2, linestyle = 'dotted')
axes.text(340, .07, 'Old Method', color='red')
axes.text(340, .064, 'New Method #2', color='green')
axes.text(340, .058, 'New Method #3', color='blue')
axes.text(365, .07, 'Old Method Temp Corrected', color='pink')
axes.text(365, .064, 'New Method #2  Temp Corrected', color='lightgreen')
axes.text(365, .058, 'New Method #3  Temp Corrected', color='lightblue')
plt.title('Range of Data')
plt.tight_layout()

#plt.legend()
plt.grid(axis='y')

plt.savefig("../../Dissertation_projects/Absorption_experiments/Figs/Error_test_figs/Range_methods_temp_corr.png")

# %% [markdown]
# df_old_temp_corrected = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_old_method_temp_cor.csv', sep=',', index_col=0)
# df_old_temp_corrected_copy = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_old_method_temp_cor.csv', sep=',', index_col=0)
# list_cols_old = df_old_temp_corrected_copy.columns
#
# df_old_temp_corrected = df_old_temp_corrected[[col for col in df_old_temp_corrected.columns if col in list_cols_old]]
#
# df_o = df_old_temp_corrected
#
#
# # Calculate RMSE and mean for each row OLD
# df_old_temp_corrected['mean'] = df_o.mean(axis=1)
# df_old_temp_corrected['rmse'] = np.sqrt(((df_o.sub(df_o.mean(axis=1), axis=0)) ** 2).mean(axis=1))
# df_old_temp_corrected['rmse_up'] = df_old_temp_corrected['mean'] + df_old_temp_corrected['rmse']
# df_old_temp_corrected['rmse_down'] = df_old_temp_corrected['mean'] - df_old_temp_corrected['rmse']
#
# df_old_temp_corrected['sem'] = df_o.sem(axis=1)
# df_old_temp_corrected['sem_up'] = df_old_temp_corrected['mean'] + df_old_temp_corrected['sem']
# df_old_temp_corrected['sem_down'] = df_old_temp_corrected['mean'] - df_old_temp_corrected['sem']
#
# df_old_temp_corrected['min'] = df_o.min(axis=1)
# df_old_temp_corrected['max'] = df_o.max(axis=1)
# df_old_temp_corrected['range'] = df_old_temp_corrected['max'] - df_old_temp_corrected['min']
#
# df_rmse_old = df_old_temp_corrected.drop(list_cols_old, axis=1)
#
# df_rmse_old.to_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_old_method_stats_tc.csv')
# df_rmse_old
#
# #df_new_3_stats_tc = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_3_stats_tc.csv')
# #df_new_2_stats_tc = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_new_method_2_stats_tc.csv')
# #df_old_stats_tc = pd.read_csv('../../Dissertation_projects/Absorption_experiments/Data/Error_test_data/Data_output_error_test_old_method_stats_tc.csv')
