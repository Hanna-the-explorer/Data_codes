# %%
import pandas as pd #the csv reading library
import matplotlib as mpl
import matplotlib.pyplot as plt #the ploting library
import glob #to get file names
import numpy as np
from pandas import Series
import seaborn as sns
from matplotlib.pyplot import figure
import cmocean.cm as cmo
import seaborn as sns

# %%
files = glob.glob('../Dissertation_projects/Data/CDOM/Spectra/sprectra_pchip_baseline_corrected_WC*.csv')
path_save = '../Dissertation_projects/Data/CDOM/sprectra_pchip_baseline_corrected_WC.csv'

def GET_DATA(name):
    df = pd.read_csv(name, sep=',', index_col=0)
    df = pd.DataFrame(df)
    return df

frames = []
for f in files:
    df = GET_DATA(f) # runs the processing function  
    frames.append(df) # adds the new col from each scan to a part of frames 
df = pd.concat(frames, axis=0, ignore_index=False)

df.to_csv(path_save)

df
# Out:
#                 250       251       252       253       254       255  \
# Sample_ID
# 212831     1.582213  1.166499  1.145509  1.116018  1.132758  0.999233
# 212831     1.420738  1.265245  1.118060  1.088025  1.124283  1.010358
# 212831     1.238159  1.200902  1.181345  1.141725  1.070125  1.011730
# 212832     1.394769  1.070396  1.024167  1.060669  1.073567  0.884572
# 212832     1.741549  1.055882  1.004097  0.949880  0.958139  0.897783
# ...             ...       ...       ...       ...       ...       ...
# 225339     6.665595  6.690608  6.790543  6.745253  6.841794  6.891832
# 225339     7.268334  6.669069  6.778397  6.863410  6.811121  6.912300
# 225340     6.334720  6.691976  6.774561  6.781040  6.859812  6.861516
# 225340     6.804391  6.663968  6.683565  6.762730  6.843894  6.940784
# 225340     6.792858  6.583371  6.758450  6.753453  6.911491  6.969247
#
#                 256       257       258       259  ...       742       743  \
# Sample_ID                                          ...
# 212831     1.143973  0.951363  1.026407  0.910059  ...  0.005911 -0.064835
# 212831     1.075508  0.890705  0.961718  0.842312  ...  0.018489 -0.046055
# 212831     1.028852  0.933714  0.964997  0.833017  ... -0.031730 -0.077650
# 212832     0.912095  0.816238  0.879382  0.750754  ...  0.011030 -0.054474
# 212832     0.838781  0.822236  0.882299  0.743585  ...  0.014679 -0.051466
# ...             ...       ...       ...       ...  ...       ...       ...
# 225339     7.223834  7.041561  7.045235  6.984060  ... -0.037576 -0.034993
# 225339     7.216803  7.070359  7.037288  7.138603  ... -0.036480 -0.036655
# 225340     7.002140  6.981377  7.088624  7.072872  ... -0.029396 -0.028245
# 225340     7.067142  7.012585  7.085218  7.144850  ... -0.027320 -0.031065
# 225340     7.011406  6.966007  7.097989  7.098235  ... -0.030101 -0.029905
#
#                 744       745       746       747       748       749  \
# Sample_ID
# 212831    -0.021710 -0.010134 -0.025082  0.025395 -0.000109 -0.009462
# 212831    -0.019706 -0.029208 -0.018237  0.026505 -0.036312  0.003975
# 212831    -0.037224 -0.017875 -0.051179 -0.002181 -0.018689  0.017750
# 212832    -0.035269 -0.028743 -0.048554  0.010549 -0.010062  0.006566
# 212832    -0.013435 -0.045746 -0.043932  0.013124 -0.035846 -0.002576
# ...             ...       ...       ...       ...       ...       ...
# 225339    -0.031813 -0.039250 -0.029383 -0.025650 -0.018625 -0.026296
# 225339    -0.036356 -0.039352 -0.030327 -0.016693 -0.010653 -0.027131
# 225340    -0.029521 -0.032736 -0.022937 -0.017376 -0.005930 -0.016888
# 225340    -0.026638 -0.034541 -0.020853 -0.015186 -0.013349 -0.019187
# 225340    -0.029764 -0.031607 -0.025375 -0.004151 -0.009187 -0.018953
#
#                 750                                file_id
# Sample_ID
# 212831    -0.024127  WC_Abs_GoM21Su_ID212831_Absorbance_01
# 212831    -0.041649  WC_Abs_GoM21Su_ID212831_Absorbance_02
# 212831    -0.064039  WC_Abs_GoM21Su_ID212831_Absorbance_03
# 212832    -0.047155  WC_Abs_GoM21Su_ID212832_Absorbance_01
# 212832    -0.035792  WC_Abs_GoM21Su_ID212832_Absorbance_02
# ...             ...                                    ...
# 225339    -0.026104                           225339_1_103
# 225339    -0.020028                           225339_2_104
# 225340    -0.005612                           225340_0_105
# 225340    -0.019344                           225340_1_106
# 225340    -0.019736                           225340_2_107
#
# [1191 rows x 502 columns]

# %%
files = glob.glob('../Dissertation_projects/Data/CDOM/Outputs/*.csv')
path_save = '../Dissertation_projects/Data/CDOM/Outputs.csv'

def GET_DATA(name):
    df = pd.read_csv(name, sep=',', index_col=0)
    df = pd.DataFrame(df)
    return df

frames = []
for f in files:
    df = GET_DATA(f) # runs the processing function  
    frames.append(df) # adds the new col from each scan to a part of frames 
df = pd.concat(frames, axis=0, ignore_index=False)

df.to_csv(path_save)

df
# Out:
#            ss_275_700_sem  ss_275_295_sem  ss_350_400_sem  R2_275_700_sem  \
# Sample_ID
# 212841           0.001834       -0.000023        0.000010        0.305639
# 212842           0.000907        0.019669        0.076550        0.243833
# 212843           0.001261        0.007845        0.065689        0.261506
# 212844           0.000969        0.021487        0.057443        0.231947
# 212845           0.000719        0.021273        0.045298        0.217324
# ...                   ...             ...             ...             ...
# 225339           0.014998        0.000011        0.017791        0.996142
# 225339           0.014984        0.000011        0.018014        0.996043
# 225340           0.015729        0.000010        0.017902        0.995729
# 225340           0.015737        0.000012        0.017864        0.995639
# 225340           0.015736        0.000012        0.017958        0.995615
#
#            R2_275_295_sem  R2_350_400_sem    SR_sem  ss_275_700_hm  \
# Sample_ID
# 212841           0.943013        0.152900 -2.274347       0.000331
# 212842           0.978658        0.066023  0.256947       0.000270
# 212843           0.961288        0.073936  0.119433       0.000315
# 212844           0.975402        0.147222  0.374059       0.000244
# 212845           0.976664        0.281609  0.469633       0.000305
# ...                   ...             ...       ...            ...
# 225339           0.923991        0.999922  0.000642       4.675373
# 225339           0.905679        0.999917  0.000598       4.670820
# 225340           0.926634        0.999909  0.000556       4.909887
# 225340           0.924353        0.999921  0.000650       4.912218
# 225340           0.915385        0.999925  0.000679       4.911638
#
#            ss_275_295_hm  ss_350_400_hm  ...  acdom_412  acdom_440  acdom_700  \
# Sample_ID                                ...
# 212841         -0.006280       0.004274  ...  -1.247038  -1.231923  -1.024272
# 212842         -0.005062      27.194942  ...  -1.237989  -1.207604  -1.010481
# 212843         -0.015135      -0.001902  ...  -1.239459  -1.226240  -1.019027
# 212844         -0.004843      -0.001925  ...  -1.213233  -1.215002  -1.021803
# 212845         -0.005349      -0.001881  ...  -1.210582  -1.215310  -1.012608
# ...                  ...            ...  ...        ...        ...        ...
# 225339          0.003269       5.634298  ...   0.899054   0.543448  -0.066134
# 225339          0.003441       5.717773  ...   0.896159   0.545567  -0.064435
# 225340          0.003573       5.676094  ...   0.644566   0.298928  -0.187712
# 225340          0.003489       5.661219  ...   0.637880   0.295582  -0.190617
# 225340          0.003326       5.696654  ...   0.636270   0.291136  -0.192407
#
#            acdom_254_bc  acdom_320_bc  acdom_350_bc  acdom_412_bc  \
# Sample_ID
# 212841         5.263260     -1.289680     -1.287355     -1.247038
# 212842        13.145632     -1.214458     -1.255106     -1.237989
# 212843        12.390709     -1.225455     -1.252817     -1.239459
# 212844        12.098104     -1.191687     -1.232101     -1.213233
# 212845        12.180376     -1.173004     -1.225218     -1.210582
# ...                 ...           ...           ...           ...
# 225339         6.777793      4.482194      2.676725      0.899054
# 225339         6.747367      4.480536      2.675890      0.896159
# 225340         6.678153      4.186253      2.395723      0.644566
# 225340         6.661912      4.194541      2.391418      0.637880
# 225340         6.728779      4.195732      2.390451      0.636270
#
#            acdom_440_bc  acdom_700_bc  \
# Sample_ID
# 212841        -1.231923     -1.024272
# 212842        -1.207604     -1.010481
# 212843        -1.226240     -1.019027
# 212844        -1.215002     -1.021803
# 212845        -1.215310     -1.012608
# ...                 ...           ...
# 225339         0.543448     -0.066134
# 225339         0.545567     -0.064435
# 225340         0.298928     -0.187712
# 225340         0.295582     -0.190617
# 225340         0.291136     -0.192407
#
#                                                    file_id
# Sample_ID
# 212841     BC_Abs_GoM21Su_ID212841_Absorbance_22-30-57-574
# 212842     BC_Abs_GoM21Su_ID212842_Absorbance_22-32-48-080
# 212843     BC_Abs_GoM21Su_ID212843_Absorbance_22-34-56-876
# 212844     BC_Abs_GoM21Su_ID212844_Absorbance_22-36-55-362
# 212845     BC_Abs_GoM21Su_ID212845_Absorbance_22-38-48-230
# ...                                                    ...
# 225339                                        225339_1_103
# 225339                                        225339_2_104
# 225340                                        225340_0_105
# 225340                                        225340_1_106
# 225340                                        225340_2_107
#
# [6373 rows x 30 columns]
